# %% [markdown]
# # Ray Tune - Search Algorithms and Schedulers
#
# © 2019-2020, Anyscale. All Rights Reserved
#
# ![Anyscale Academy](../images/AnyscaleAcademy_Logo_clearbanner_141x100.png)
#
# This notebook introduces the concepts of search algorithms and schedulers which help optimize HPO. We'll see an example that combines the use of one search algorithm and one schedulers.
#
# The full set of search algorithms provided by Tune is documented [here](https://docs.ray.io/en/latest/tune/api_docs/suggestion.html), along with information about implementing your own. The full set of schedulers provided is documented [here](https://docs.ray.io/en/latest/tune/api_docs/schedulers.html).

# %% [markdown]
# ## About Search Algorithms
#
# Tune integrates many [open source optimization libraries](https://docs.ray.io/en/latest/tune/api_docs/suggestion.html), each of which defines the parameter search space in its own way. Hence, you should read the corresponding documentation for an algorithm to understand the particular details of using it.
#
# Some of the search algorithms supported include the following:
#
# * [Bayesian Optimization](https://github.com/fmfn/BayesianOptimization): This constrained global optimization process builds upon bayesian inference and gaussian processes. It attempts to find the maximum value of an unknown function in as few iterations as possible. This is a good technique for optimization of high cost functions.
# * [BOHB (Bayesian Optimization HyperBand](https://github.com/automl/HpBandSter): An algorithm that both terminates bad trials and also uses Bayesian Optimization to improve the hyperparameter search. It is backed by the [HpBandSter](https://docs.ray.io/en/latest/tune/api_docs/schedulers.html#tune-scheduler-bohb) library. BOHB is intended to be paired with a specific scheduler class: [HyperBandForBOHB](https://docs.ray.io/en/latest/tune/api_docs/schedulers.html#tune-scheduler-bohb).
# * [HyperOpt](http://hyperopt.github.io/hyperopt): A Python library for serial and parallel optimization over awkward search spaces, which may include real-valued, discrete, and conditional dimensions.
# * [Nevergrad](https://github.com/facebookresearch/nevergrad): HPO without computing gradients.
#
# These and other algorithms are described in the [documentation](https://docs.ray.io/en/latest/tune/api_docs/suggestion.html).
#
# A limitation of search algorithms used by themselves is they can't affect or stop training processes, for example early stopping of trail that are performing poorly. The schedulers can do this, so it's common to use a compatible search algorithm with a scheduler, as we'll show in the first example.

# %% [markdown]
# ## About Schedulers
#
# Tune includes distributed implementations of several early-stopping algorithms, including the following:
#
# * [Median Stopping Rule](https://research.google.com/pubs/pub46180.html): It applies the simple rule that a trial is aborted if the results are trending below the median of the previous trials.
# * [HyperBand](https://arxiv.org/abs/1603.06560): It structures search as an _infinite-armed, stochastic, exploration-only, multi-armed bandit_. See the [Multi-Armed Bandits lessons](../ray-rllib/multi-armed-bandits/00-Multi-Armed-Bandits-Overview.ipynb) for information on these concepts. The infinite arms correspond to the tunable parameters. Trying values stochastically ensures quick exploration of the parameter space. Exploration-only is desirable because for HPO, we aren't interested in _exploiting_ parameter combinations we've already tried (the usual case when using MABs where rewards are the goal). Intead, we need to explore as many new parameter combinations as possible.
# * [ASHA](https://openreview.net/forum?id=S1Y7OOlRZ). This is an aynchronous version of HyperBand that improves on the latter. Hence it is recommended over the original HyperBand implementation.
#
# Tune also includes a distributed implementation of [Population Based Training (PBT)](https://deepmind.com/blog/population-based-training-neural-networks). When the PBT scheduler is enabled, each trial variant is treated as a member of the _population_. Periodically, top-performing trials are checkpointed, which means your [`tune.Trainable`](https://docs.ray.io/en/latest/tune/api_docs/trainable.html#tune-trainable) object (e.g., the `TrainMNist` class we used in the previous exercise) has to support save and restore.
#
# Low-performing trials clone the checkpoints of top performers and perturb the configurations in the hope of discovering an even better variation. PBT trains a group of models (or RLlib agents) in parallel. So, unlike other hyperparameter search algorithms, PBT mutates hyperparameters during training time. This enables very fast hyperparameter discovery and also automatically discovers good [annealing](https://en.wikipedia.org/wiki/Simulated_annealing) schedules.
#
# See the [Tune schedulers](https://docs.ray.io/en/latest/tune/api_docs/schedulers.html) for a complete list and descriptions.

# %% [markdown]
# ## Examples
#
# Let's initialize Ray as before:

# %%
# !../tools/start-ray.sh --check --verbose
# Out:
# INFO: Ray is already running.

# %%
import ray
from ray import tune

# %%
ray.init(address='auto', ignore_reinit_error=True)
# Out:
# {'node_ip_address': '192.168.1.149',
#  'raylet_ip_address': '192.168.1.149',
#  'redis_address': '192.168.1.149:6379',
#  'object_store_address': '/tmp/ray/session_2020-07-18_09-21-16_202196_93175/sockets/plasma_store',
#  'raylet_socket_name': '/tmp/ray/session_2020-07-18_09-21-16_202196_93175/sockets/raylet',
#  'webui_url': 'localhost:8265',
#  'session_dir': '/tmp/ray/session_2020-07-18_09-21-16_202196_93175'}

# %% [markdown]
# ### BOHB
#
# BOHB (Bayesian Optimization HyperBand) is an algorithm that both terminates bad trials and also uses Bayesian Optimization to improve the hyperparameter search. The [Tune implementation](https://docs.ray.io/en/latest/tune/api_docs/suggestion.html#bohb-tune-suggest-bohb-tunebohb) is backed by the [HpBandSter library](https://github.com/automl/HpBandSter), which we must install, along with [ConfigSpace](https://automl.github.io/HpBandSter/build/html/quickstart.html#searchspace), which is used to define the search space specification:

# %%
# !pip install hpbandster ConfigSpace
# Out:
# 2020-07-19 08:01:45,019	WARNING import_thread.py:136 -- The actor 'ImplicitFunc' has been exported 100 times. It's possible that this warning is accidental, but this may indicate that the same remote function is being defined repeatedly from within many tasks and exported to all of the workers. This can be a performance issue and can be resolved by defining the remote function on the driver instead. See https://github.com/ray-project/ray/issues/6240 for more discussion.
# Requirement already satisfied: hpbandster in /Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages (0.7.4)
# Requirement already satisfied: ConfigSpace in /Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages (0.4.13)
# Requirement already satisfied: Pyro4 in /Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages (from hpbandster) (4.80)
# Requirement already satisfied: statsmodels in /Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages (from hpbandster) (0.11.1)
# Requirement already satisfied: scipy in /Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages (from hpbandster) (1.4.1)
# Requirement already satisfied: netifaces in /Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages (from hpbandster) (0.10.9)
# Requirement already satisfied: serpent in /Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages (from hpbandster) (1.30.2)
# Requirement already satisfied: numpy in /Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages (from hpbandster) (1.18.1)
# Requirement already satisfied: cython in /Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages (from ConfigSpace) (0.29.21)
# Requirement already satisfied: pyparsing in /Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages (from ConfigSpace) (2.4.7)
# Requirement already satisfied: pandas>=0.21 in /Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages (from statsmodels->hpbandster) (1.0.3)
# Requirement already satisfied: patsy>=0.5 in /Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages (from statsmodels->hpbandster) (0.5.1)
# Requirement already satisfied: pytz>=2017.2 in /Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages (from pandas>=0.21->statsmodels->hpbandster) (2019.3)
# Requirement already satisfied: python-dateutil>=2.6.1 in /Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages (from pandas>=0.21->statsmodels->hpbandster) (2.8.1)
# Requirement already satisfied: six in /Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages (from patsy>=0.5->statsmodels->hpbandster) (1.14.0)

# %% [markdown]
# We use BOHB with the scheduler [HyperBandForBOHB](https://docs.ray.io/en/latest/tune/api_docs/schedulers.html#bohb-tune-schedulers-hyperbandforbohb).

# %% [markdown]
# Let's try it. We'll use the same MNIST example from the previous lesson, but this time, we'll import the code from a file in this directory, `mnist.py`. Note that the implementation of `TrainMNIST` in the file has enhancements not present in the previous lesson, such as methods to support saving and restoring checkpoints, which are required to be used here. See the code comments for details.

# %%
from mnist import ConvNet, TrainMNIST, EPOCH_SIZE, TEST_SIZE, DATA_ROOT

# %% [markdown]
# Import and configure the `ConfigSpace` object we need for the search algorithm.

# %%
import ConfigSpace as CS
from ray.tune.schedulers.hb_bohb import HyperBandForBOHB
from ray.tune.suggest.bohb import TuneBOHB

# %%
config_space = CS.ConfigurationSpace()

# There are also UniformIntegerHyperparameter and UniformFloatHyperparameter
# objects for defining integer and float ranges, respectively. For example:
# config_space.add_hyperparameter(
#     CS.UniformIntegerHyperparameter('foo', lower=0, upper=100))

config_space.add_hyperparameter(
    CS.CategoricalHyperparameter('lr', choices=[0.001, 0.01, 0.1]))
config_space.add_hyperparameter(
    CS.CategoricalHyperparameter('momentum', choices=[0.001, 0.01, 0.1, 0.9]))

config_space
# Out:
# Configuration space object:
#   Hyperparameters:
#     lr, Type: Categorical, Choices: {0.001, 0.01, 0.1}, Default: 0.001
#     momentum, Type: Categorical, Choices: {0.001, 0.01, 0.1, 0.9}, Default: 0.001

# %%
experiment_metrics = dict(metric="mean_accuracy", mode="max")

search_algorithm = TuneBOHB(config_space, max_concurrent=4, **experiment_metrics)

scheduler = HyperBandForBOHB(
    time_attr='training_iteration',
    reduction_factor=4,
    max_t=200,
    **experiment_metrics)

# %% [markdown]
# Through experimentation, we determined that `max_t=200` is necessary to get good results. For the smallest learning rate and momentum values, it takes longer for training to converge.

# %%
analysis = tune.run(TrainMNIST, 
    scheduler=scheduler, 
    search_alg=search_algorithm, 
    num_samples=12,                           # Force it try all 12 combinations
    verbose=2,                                # Change to 0 or 1 to reduce the output.
    ray_auto_init=False                       # Don't allow Tune to initialize Ray.
)
# Out:
# == Status ==<br>Memory usage on this node: 9.8/16.0 GiB<br>Using HyperBand: num_stopped=0 total_brackets=2
# Round #0:
#   None
#   Bracket(Max Size (n)=80, Milestone (r)=3, completed=0.0%): {PENDING: 3, RUNNING: 1} <br>Resources requested: 1/8 CPUs, 0/0 GPUs, 0.0/4.59 GiB heap, 0.0/1.56 GiB objects<br>Result logdir: /Users/deanwampler/ray_results/TrainMNIST<br>Number of trials: 4 (3 PENDING, 1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name         </th><th>status  </th><th>loc  </th><th style="text-align: right;">   lr</th><th style="text-align: right;">  momentum</th></tr>
# </thead>
# <tbody>
# <tr><td>TrainMNIST_c4a1a4b4</td><td>RUNNING </td><td>     </td><td style="text-align: right;">0.01 </td><td style="text-align: right;">     0.001</td></tr>
# <tr><td>TrainMNIST_c4a1ce80</td><td>PENDING </td><td>     </td><td style="text-align: right;">0.1  </td><td style="text-align: right;">     0.01 </td></tr>
# <tr><td>TrainMNIST_c4a1ef6e</td><td>PENDING </td><td>     </td><td style="text-align: right;">0.001</td><td style="text-align: right;">     0.01 </td></tr>
# <tr><td>TrainMNIST_c4a2102a</td><td>PENDING </td><td>     </td><td style="text-align: right;">0.01 </td><td style="text-align: right;">     0.9  </td></tr>
# </tbody>
# </table><br><br>
# Result for TrainMNIST_c4a1a4b4:
#   date: 2020-07-19_08-01-49
#   done: false
#   experiment_id: bc79054f24c84d0f8de02eb418e668d1
#   experiment_tag: 1_lr=0.01,momentum=0.001
#   hostname: DWAnyscaleMBP.local
#   iterations_since_restore: 1
#   mean_accuracy: 0.159375
#   node_ip: 192.168.1.149
#   pid: 25149
#   time_since_restore: 0.20097112655639648
#   time_this_iter_s: 0.20097112655639648
#   time_total_s: 0.20097112655639648
#   timestamp: 1595170909
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: c4a1a4b4
#
# Result for TrainMNIST_c4a1ce80:
#   date: 2020-07-19_08-01-49
#   done: false
#   experiment_id: c132d028028c4b3cb198d349abc182ef
#   experiment_tag: 2_lr=0.1,momentum=0.01
#   hostname: DWAnyscaleMBP.local
#   iterations_since_restore: 1
#   mean_accuracy: 0.5375
#   node_ip: 192.168.1.149
#   pid: 25148
#   time_since_restore: 0.20450210571289062
#   time_this_iter_s: 0.20450210571289062
#   time_total_s: 0.20450210571289062
#   timestamp: 1595170909
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: c4a1ce80
#
# Result for TrainMNIST_c4a1ef6e:
#   date: 2020-07-19_08-01-49
#   done: false
#   experiment_id: 8ae67266fc6a41fdb8ce381454d01d81
#   experiment_tag: 3_lr=0.001,momentum=0.01
#   hostname: DWAnyscaleMBP.local
#   iterations_since_restore: 1
#   mean_accuracy: 0.09375
#   node_ip: 192.168.1.149
#   pid: 25147
#   time_since_restore: 0.20981717109680176
#   time_this_iter_s: 0.20981717109680176
#   time_total_s: 0.20981717109680176
#   timestamp: 1595170909
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: c4a1ef6e
#
# Result for TrainMNIST_c4a2102a:
#   date: 2020-07-19_08-01-49
#   done: false
#   experiment_id: 98333a4fe4bc4e7fb492a3bd604acab5
#   experiment_tag: 4_lr=0.01,momentum=0.9
#   hostname: DWAnyscaleMBP.local
#   iterations_since_restore: 1
#   mean_accuracy: 0.28125
#   node_ip: 192.168.1.149
#   pid: 25193
#   time_since_restore: 0.3379991054534912
#   time_this_iter_s: 0.3379991054534912
#   time_total_s: 0.3379991054534912
#   timestamp: 1595170909
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: c4a2102a
#
# Result for TrainMNIST_c6437144:
#   date: 2020-07-19_08-01-52
#   done: false
#   experiment_id: c015f2827a4a46c38b4e05fdbfe407c2
#   experiment_tag: 8_lr=0.001,momentum=0.9
#   hostname: DWAnyscaleMBP.local
#   iterations_since_restore: 1
#   mean_accuracy: 0.06875
#   node_ip: 192.168.1.149
#   pid: 25205
#   time_since_restore: 0.20524120330810547
#   time_this_iter_s: 0.20524120330810547
#   time_total_s: 0.20524120330810547
#   timestamp: 1595170912
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: c6437144
#
# Result for TrainMNIST_c5b631e4:
#   date: 2020-07-19_08-01-52
#   done: false
#   experiment_id: 88c2f848b44b414b867431e2888bb8a4
#   experiment_tag: 6_lr=0.1,momentum=0.01
#   hostname: DWAnyscaleMBP.local
#   iterations_since_restore: 1
#   mean_accuracy: 0.46875
#   node_ip: 192.168.1.149
#   pid: 25207
#   time_since_restore: 0.22042322158813477
#   time_this_iter_s: 0.22042322158813477
#   time_total_s: 0.22042322158813477
#   timestamp: 1595170912
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: c5b631e4
#
# Result for TrainMNIST_c5c661f4:
#   date: 2020-07-19_08-01-52
#   done: false
#   experiment_id: e0d3e1e1179c4bf79bd78f101f20d01c
#   experiment_tag: 7_lr=0.001,momentum=0.1
#   hostname: DWAnyscaleMBP.local
#   iterations_since_restore: 1
#   mean_accuracy: 0.16875
#   node_ip: 192.168.1.149
#   pid: 25206
#   time_since_restore: 0.22270798683166504
#   time_this_iter_s: 0.22270798683166504
#   time_total_s: 0.22270798683166504
#   timestamp: 1595170912
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: c5c661f4
#
# Result for TrainMNIST_c5ab82b2:
#   date: 2020-07-19_08-01-52
#   done: false
#   experiment_id: c0ce33e8632f4be4a1c4cb5e553d563e
#   experiment_tag: 5_lr=0.01,momentum=0.001
#   hostname: DWAnyscaleMBP.local
#   iterations_since_restore: 1
#   mean_accuracy: 0.090625
#   node_ip: 192.168.1.149
#   pid: 25208
#   time_since_restore: 0.22895383834838867
#   time_this_iter_s: 0.22895383834838867
#   time_total_s: 0.22895383834838867
#   timestamp: 1595170912
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: c5ab82b2
# == Status ==<br>Memory usage on this node: 10.3/16.0 GiB<br>Using HyperBand: num_stopped=0 total_brackets=2
# Round #0:
#   None
#   Bracket(Max Size (n)=80, Milestone (r)=3, completed=2.1%): {PAUSED: 7, RUNNING: 4} <br>Resources requested: 4/8 CPUs, 0/0 GPUs, 0.0/4.59 GiB heap, 0.0/1.56 GiB objects<br>Result logdir: /Users/deanwampler/ray_results/TrainMNIST<br>Number of trials: 11 (7 PAUSED, 4 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name         </th><th>status  </th><th>loc                </th><th style="text-align: right;">   lr</th><th style="text-align: right;">  momentum</th><th style="text-align: right;">     acc</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th></tr>
# </thead>
# <tbody>
# <tr><td>TrainMNIST_c4a1a4b4</td><td>PAUSED  </td><td>                   </td><td style="text-align: right;">0.01 </td><td style="text-align: right;">     0.001</td><td style="text-align: right;">0.296875</td><td style="text-align: right;">     3</td><td style="text-align: right;">        0.643175</td></tr>
# <tr><td>TrainMNIST_c4a1ce80</td><td>PAUSED  </td><td>                   </td><td style="text-align: right;">0.1  </td><td style="text-align: right;">     0.01 </td><td style="text-align: right;">0.678125</td><td style="text-align: right;">     3</td><td style="text-align: right;">        0.655609</td></tr>
# <tr><td>TrainMNIST_c4a1ef6e</td><td>PAUSED  </td><td>                   </td><td style="text-align: right;">0.001</td><td style="text-align: right;">     0.01 </td><td style="text-align: right;">0.1125  </td><td style="text-align: right;">     3</td><td style="text-align: right;">        0.701357</td></tr>
# <tr><td>TrainMNIST_c4a2102a</td><td>PAUSED  </td><td>                   </td><td style="text-align: right;">0.01 </td><td style="text-align: right;">     0.9  </td><td style="text-align: right;">0.496875</td><td style="text-align: right;">     3</td><td style="text-align: right;">        1.01279 </td></tr>
# <tr><td>TrainMNIST_c5ab82b2</td><td>RUNNING </td><td>192.168.1.149:25208</td><td style="text-align: right;">0.01 </td><td style="text-align: right;">     0.001</td><td style="text-align: right;">0.153125</td><td style="text-align: right;">     2</td><td style="text-align: right;">        0.444333</td></tr>
# <tr><td>TrainMNIST_c5b631e4</td><td>PAUSED  </td><td>                   </td><td style="text-align: right;">0.1  </td><td style="text-align: right;">     0.01 </td><td style="text-align: right;">0.721875</td><td style="text-align: right;">     3</td><td style="text-align: right;">        0.662265</td></tr>
# <tr><td>TrainMNIST_c5c661f4</td><td>PAUSED  </td><td>                   </td><td style="text-align: right;">0.001</td><td style="text-align: right;">     0.1  </td><td style="text-align: right;">0.1625  </td><td style="text-align: right;">     3</td><td style="text-align: right;">        0.695368</td></tr>
# <tr><td>TrainMNIST_c6437144</td><td>PAUSED  </td><td>                   </td><td style="text-align: right;">0.001</td><td style="text-align: right;">     0.9  </td><td style="text-align: right;">0.046875</td><td style="text-align: right;">     3</td><td style="text-align: right;">        0.639237</td></tr>
# <tr><td>TrainMNIST_c787ca1e</td><td>RUNNING </td><td>                   </td><td style="text-align: right;">0.01 </td><td style="text-align: right;">     0.1  </td><td style="text-align: right;">        </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td></tr>
# <tr><td>TrainMNIST_c7946260</td><td>RUNNING </td><td>                   </td><td style="text-align: right;">0.001</td><td style="text-align: right;">     0.001</td><td style="text-align: right;">        </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td></tr>
# <tr><td>TrainMNIST_c7a21fd6</td><td>RUNNING </td><td>                   </td><td style="text-align: right;">0.1  </td><td style="text-align: right;">     0.1  </td><td style="text-align: right;">        </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td></tr>
# </tbody>
# </table><br><br>
# Result for TrainMNIST_c787ca1e:
#   date: 2020-07-19_08-01-54
#   done: false
#   experiment_id: 11fbaaf6b8c74dde897cc48662ce07c9
#   experiment_tag: 9_lr=0.01,momentum=0.1
#   hostname: DWAnyscaleMBP.local
#   iterations_since_restore: 1
#   mean_accuracy: 0.1125
#   node_ip: 192.168.1.149
#   pid: 25213
#   time_since_restore: 0.27850914001464844
#   time_this_iter_s: 0.27850914001464844
#   time_total_s: 0.27850914001464844
#   timestamp: 1595170914
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: c787ca1e
#
# Result for TrainMNIST_c7946260:
#   date: 2020-07-19_08-01-54
#   done: false
#   experiment_id: c56eadbdb27d4e3c8b8e5974716448fa
#   experiment_tag: 10_lr=0.001,momentum=0.001
#   hostname: DWAnyscaleMBP.local
#   iterations_since_restore: 1
#   mean_accuracy: 0.06875
#   node_ip: 192.168.1.149
#   pid: 25210
#   time_since_restore: 0.2643098831176758
#   time_this_iter_s: 0.2643098831176758
#   time_total_s: 0.2643098831176758
#   timestamp: 1595170914
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: c7946260
#
# Result for TrainMNIST_c7a21fd6:
#   date: 2020-07-19_08-01-54
#   done: false
#   experiment_id: e0685c211e29497992e5561881efbc6b
#   experiment_tag: 11_lr=0.1,momentum=0.1
#   hostname: DWAnyscaleMBP.local
#   iterations_since_restore: 1
#   mean_accuracy: 0.625
#   node_ip: 192.168.1.149
#   pid: 25217
#   time_since_restore: 0.23972010612487793
#   time_this_iter_s: 0.23972010612487793
#   time_total_s: 0.23972010612487793
#   timestamp: 1595170914
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: c7a21fd6
#
# Result for TrainMNIST_c7aeb8a4:
#   date: 2020-07-19_08-01-54
#   done: false
#   experiment_id: dc24002a5fd74f2c8a9651114b17d102
#   experiment_tag: 12_lr=0.01,momentum=0.01
#   hostname: DWAnyscaleMBP.local
#   iterations_since_restore: 1
#   mean_accuracy: 0.1125
#   node_ip: 192.168.1.149
#   pid: 25212
#   time_since_restore: 0.23923683166503906
#   time_this_iter_s: 0.23923683166503906
#   time_total_s: 0.23923683166503906
#   timestamp: 1595170914
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: c7aeb8a4
# 2020-07-19 08:01:55,058	WARNING import_thread.py:136 -- The actor 'TrainMNIST' has been exported 100 times. It's possible that this warning is accidental, but this may indicate that the same remote function is being defined repeatedly from within many tasks and exported to all of the workers. This can be a performance issue and can be resolved by defining the remote function on the driver instead. See https://github.com/ray-project/ray/issues/6240 for more discussion.
# (pid=25209) 2020-07-19 08:01:57,682	INFO trainable.py:423 -- Restored on 192.168.1.149 from checkpoint: /Users/deanwampler/ray_results/TrainMNIST/TrainMNIST_1_lr=0.01,momentum=0.001_2020-07-19_08-01-4736q4ja5q/tmpuka90ieqrestore_from_object/checkpoint
# (pid=25209) 2020-07-19 08:01:57,682	INFO trainable.py:430 -- Current state after restoring: {'_iteration': 3, '_timesteps_total': None, '_time_total': 0.6431751251220703, '_episodes_total': None}
# (pid=25216) 2020-07-19 08:01:57,769	INFO trainable.py:423 -- Restored on 192.168.1.149 from checkpoint: /Users/deanwampler/ray_results/TrainMNIST/TrainMNIST_2_lr=0.1,momentum=0.01_2020-07-19_08-01-47e02oa8w0/tmpp5oeb8s3restore_from_object/checkpoint
# (pid=25216) 2020-07-19 08:01:57,769	INFO trainable.py:430 -- Current state after restoring: {'_iteration': 3, '_timesteps_total': None, '_time_total': 0.6556088924407959, '_episodes_total': None}
# (pid=25211) 2020-07-19 08:01:57,864	INFO trainable.py:423 -- Restored on 192.168.1.149 from checkpoint: /Users/deanwampler/ray_results/TrainMNIST/TrainMNIST_3_lr=0.001,momentum=0.01_2020-07-19_08-01-47fusp7hbd/tmpqlk23138restore_from_object/checkpoint
# (pid=25211) 2020-07-19 08:01:57,864	INFO trainable.py:430 -- Current state after restoring: {'_iteration': 3, '_timesteps_total': None, '_time_total': 0.7013571262359619, '_episodes_total': None}
# Result for TrainMNIST_c4a1a4b4:
#   date: 2020-07-19_08-01-58
#   done: false
#   experiment_id: bc79054f24c84d0f8de02eb418e668d1
#   experiment_tag: 1_lr=0.01,momentum=0.001
#   hostname: DWAnyscaleMBP.local
#   iterations_since_restore: 1
#   mean_accuracy: 0.190625
#   node_ip: 192.168.1.149
#   pid: 25209
#   time_since_restore: 0.5545248985290527
#   time_this_iter_s: 0.5545248985290527
#   time_total_s: 1.197700023651123
#   timestamp: 1595170918
#   timesteps_since_restore: 0
#   training_iteration: 4
#   trial_id: c4a1a4b4
# == Status ==<br>Memory usage on this node: 10.6/16.0 GiB<br>Using HyperBand: num_stopped=0 total_brackets=2
# Round #0:
#   None
#   Bracket(Max Size (n)=20, Milestone (r)=12, completed=3.4%): {PENDING: 4, RUNNING: 8} <br>Resources requested: 8/8 CPUs, 0/0 GPUs, 0.0/4.59 GiB heap, 0.0/1.56 GiB objects<br>Result logdir: /Users/deanwampler/ray_results/TrainMNIST<br>Number of trials: 12 (4 PENDING, 8 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name         </th><th>status  </th><th>loc                </th><th style="text-align: right;">   lr</th><th style="text-align: right;">  momentum</th><th style="text-align: right;">     acc</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th></tr>
# </thead>
# <tbody>
# <tr><td>TrainMNIST_c4a1a4b4</td><td>RUNNING </td><td>192.168.1.149:25209</td><td style="text-align: right;">0.01 </td><td style="text-align: right;">     0.001</td><td style="text-align: right;">0.190625</td><td style="text-align: right;">     4</td><td style="text-align: right;">        1.1977  </td></tr>
# <tr><td>TrainMNIST_c4a1ce80</td><td>RUNNING </td><td>                   </td><td style="text-align: right;">0.1  </td><td style="text-align: right;">     0.01 </td><td style="text-align: right;">0.678125</td><td style="text-align: right;">     3</td><td style="text-align: right;">        0.655609</td></tr>
# <tr><td>TrainMNIST_c4a1ef6e</td><td>RUNNING </td><td>                   </td><td style="text-align: right;">0.001</td><td style="text-align: right;">     0.01 </td><td style="text-align: right;">0.1125  </td><td style="text-align: right;">     3</td><td style="text-align: right;">        0.701357</td></tr>
# <tr><td>TrainMNIST_c4a2102a</td><td>RUNNING </td><td>                   </td><td style="text-align: right;">0.01 </td><td style="text-align: right;">     0.9  </td><td style="text-align: right;">0.496875</td><td style="text-align: right;">     3</td><td style="text-align: right;">        1.01279 </td></tr>
# <tr><td>TrainMNIST_c5ab82b2</td><td>RUNNING </td><td>                   </td><td style="text-align: right;">0.01 </td><td style="text-align: right;">     0.001</td><td style="text-align: right;">0.2625  </td><td style="text-align: right;">     3</td><td style="text-align: right;">        0.715963</td></tr>
# <tr><td>TrainMNIST_c5b631e4</td><td>RUNNING </td><td>                   </td><td style="text-align: right;">0.1  </td><td style="text-align: right;">     0.01 </td><td style="text-align: right;">0.721875</td><td style="text-align: right;">     3</td><td style="text-align: right;">        0.662265</td></tr>
# <tr><td>TrainMNIST_c5c661f4</td><td>RUNNING </td><td>                   </td><td style="text-align: right;">0.001</td><td style="text-align: right;">     0.1  </td><td style="text-align: right;">0.1625  </td><td style="text-align: right;">     3</td><td style="text-align: right;">        0.695368</td></tr>
# <tr><td>TrainMNIST_c6437144</td><td>RUNNING </td><td>                   </td><td style="text-align: right;">0.001</td><td style="text-align: right;">     0.9  </td><td style="text-align: right;">0.046875</td><td style="text-align: right;">     3</td><td style="text-align: right;">        0.639237</td></tr>
# <tr><td>TrainMNIST_c787ca1e</td><td>PENDING </td><td>                   </td><td style="text-align: right;">0.01 </td><td style="text-align: right;">     0.1  </td><td style="text-align: right;">0.19375 </td><td style="text-align: right;">     3</td><td style="text-align: right;">        0.755553</td></tr>
# <tr><td>TrainMNIST_c7946260</td><td>PENDING </td><td>                   </td><td style="text-align: right;">0.001</td><td style="text-align: right;">     0.001</td><td style="text-align: right;">0.05    </td><td style="text-align: right;">     3</td><td style="text-align: right;">        0.729817</td></tr>
# <tr><td>TrainMNIST_c7a21fd6</td><td>PENDING </td><td>                   </td><td style="text-align: right;">0.1  </td><td style="text-align: right;">     0.1  </td><td style="text-align: right;">0.75    </td><td style="text-align: right;">     3</td><td style="text-align: right;">        0.721295</td></tr>
# <tr><td>TrainMNIST_c7aeb8a4</td><td>PENDING </td><td>                   </td><td style="text-align: right;">0.01 </td><td style="text-align: right;">     0.01 </td><td style="text-align: right;">0.234375</td><td style="text-align: right;">     3</td><td style="text-align: right;">        0.722653</td></tr>
# </tbody>
# </table><br><br>
# Result for TrainMNIST_c4a1ef6e:
#   date: 2020-07-19_08-01-58
#   done: false
#   experiment_id: 8ae67266fc6a41fdb8ce381454d01d81
#   experiment_tag: 3_lr=0.001,momentum=0.01
#   hostname: DWAnyscaleMBP.local
#   iterations_since_restore: 1
#   mean_accuracy: 0.121875
#   node_ip: 192.168.1.149
#   pid: 25211
#   time_since_restore: 0.43152594566345215
#   time_this_iter_s: 0.43152594566345215
#   time_total_s: 1.132883071899414
#   timestamp: 1595170918
#   timesteps_since_restore: 0
#   training_iteration: 4
#   trial_id: c4a1ef6e
#
# Result for TrainMNIST_c4a1ce80:
#   date: 2020-07-19_08-01-58
#   done: false
#   experiment_id: c132d028028c4b3cb198d349abc182ef
#   experiment_tag: 2_lr=0.1,momentum=0.01
#   hostname: DWAnyscaleMBP.local
#   iterations_since_restore: 1
#   mean_accuracy: 0.63125
#   node_ip: 192.168.1.149
#   pid: 25216
#   time_since_restore: 0.5355730056762695
#   time_this_iter_s: 0.5355730056762695
#   time_total_s: 1.1911818981170654
#   timestamp: 1595170918
#   timesteps_since_restore: 0
#   training_iteration: 4
#   trial_id: c4a1ce80
#
# (pid=25246) 2020-07-19 08:01:59,084	INFO trainable.py:423 -- Restored on 192.168.1.149 from checkpoint: /Users/deanwampler/ray_results/TrainMNIST/TrainMNIST_6_lr=0.1,momentum=0.01_2020-07-19_08-01-49azho76dy/tmpwrm6r_r4restore_from_object/checkpoint
# (pid=25246) 2020-07-19 08:01:59,084	INFO trainable.py:430 -- Current state after restoring: {'_iteration': 3, '_timesteps_total': None, '_time_total': 0.6622653007507324, '_episodes_total': None}
# (pid=25245) 2020-07-19 08:01:59,142	INFO trainable.py:423 -- Restored on 192.168.1.149 from checkpoint: /Users/deanwampler/ray_results/TrainMNIST/TrainMNIST_4_lr=0.01,momentum=0.9_2020-07-19_08-01-47anfhm8wd/tmp6ufzzp5trestore_from_object/checkpoint
# (pid=25245) 2020-07-19 08:01:59,142	INFO trainable.py:430 -- Current state after restoring: {'_iteration': 3, '_timesteps_total': None, '_time_total': 1.0127880573272705, '_episodes_total': None}
# (pid=25244) 2020-07-19 08:01:59,209	INFO trainable.py:423 -- Restored on 192.168.1.149 from checkpoint: /Users/deanwampler/ray_results/TrainMNIST/TrainMNIST_7_lr=0.001,momentum=0.1_2020-07-19_08-01-49wtev965n/tmp_arexzcrrestore_from_object/checkpoint
# (pid=25244) 2020-07-19 08:01:59,209	INFO trainable.py:430 -- Current state after restoring: {'_iteration': 3, '_timesteps_total': None, '_time_total': 0.6953678131103516, '_episodes_total': None}
# (pid=25247) 2020-07-19 08:01:59,360	INFO trainable.py:423 -- Restored on 192.168.1.149 from checkpoint: /Users/deanwampler/ray_results/TrainMNIST/TrainMNIST_5_lr=0.01,momentum=0.001_2020-07-19_08-01-49y5mdf3jx/tmp87ppbqy6restore_from_object/checkpoint
# (pid=25247) 2020-07-19 08:01:59,360	INFO trainable.py:430 -- Current state after restoring: {'_iteration': 3, '_timesteps_total': None, '_time_total': 0.7159628868103027, '_episodes_total': None}
# (pid=25242) 2020-07-19 08:01:59,445	INFO trainable.py:423 -- Restored on 192.168.1.149 from checkpoint: /Users/deanwampler/ray_results/TrainMNIST/TrainMNIST_8_lr=0.001,momentum=0.9_2020-07-19_08-01-507pthizqc/tmpnw7sa9whrestore_from_object/checkpoint
# (pid=25242) 2020-07-19 08:01:59,445	INFO trainable.py:430 -- Current state after restoring: {'_iteration': 3, '_timesteps_total': None, '_time_total': 0.6392371654510498, '_episodes_total': None}
# Result for TrainMNIST_c5b631e4:
#   date: 2020-07-19_08-01-59
#   done: false
#   experiment_id: 88c2f848b44b414b867431e2888bb8a4
#   experiment_tag: 6_lr=0.1,momentum=0.01
#   hostname: DWAnyscaleMBP.local
#   iterations_since_restore: 1
#   mean_accuracy: 0.65
#   node_ip: 192.168.1.149
#   pid: 25246
#   time_since_restore: 0.49160194396972656
#   time_this_iter_s: 0.49160194396972656
#   time_total_s: 1.153867244720459
#   timestamp: 1595170919
#   timesteps_since_restore: 0
#   training_iteration: 4
#   trial_id: c5b631e4
#
# Result for TrainMNIST_c4a2102a:
#   date: 2020-07-19_08-01-59
#   done: false
#   experiment_id: 98333a4fe4bc4e7fb492a3bd604acab5
#   experiment_tag: 4_lr=0.01,momentum=0.9
#   hostname: DWAnyscaleMBP.local
#   iterations_since_restore: 1
#   mean_accuracy: 0.134375
#   node_ip: 192.168.1.149
#   pid: 25245
#   time_since_restore: 0.4544403553009033
#   time_this_iter_s: 0.4544403553009033
#   time_total_s: 1.4672284126281738
#   timestamp: 1595170919
#   timesteps_since_restore: 0
#   training_iteration: 4
#   trial_id: c4a2102a
#
# Result for TrainMNIST_c5c661f4:
#   date: 2020-07-19_08-01-59
#   done: false
#   experiment_id: e0d3e1e1179c4bf79bd78f101f20d01c
#   experiment_tag: 7_lr=0.001,momentum=0.1
#   hostname: DWAnyscaleMBP.local
#   iterations_since_restore: 1
#   mean_accuracy: 0.11875
#   node_ip: 192.168.1.149
#   pid: 25244
#   time_since_restore: 0.4700782299041748
#   time_this_iter_s: 0.4700782299041748
#   time_total_s: 1.1654460430145264
#   timestamp: 1595170919
#   timesteps_since_restore: 0
#   training_iteration: 4
#   trial_id: c5c661f4
#
# Result for TrainMNIST_c5ab82b2:
#   date: 2020-07-19_08-01-59
#   done: false
#   experiment_id: c0ce33e8632f4be4a1c4cb5e553d563e
#   experiment_tag: 5_lr=0.01,momentum=0.001
#   hostname: DWAnyscaleMBP.local
#   iterations_since_restore: 1
#   mean_accuracy: 0.15
#   node_ip: 192.168.1.149
#   pid: 25247
#   time_since_restore: 0.4302999973297119
#   time_this_iter_s: 0.4302999973297119
#   time_total_s: 1.1462628841400146
#   timestamp: 1595170919
#   timesteps_since_restore: 0
#   training_iteration: 4
#   trial_id: c5ab82b2
#
# Result for TrainMNIST_c6437144:
#   date: 2020-07-19_08-01-59
#   done: false
#   experiment_id: c015f2827a4a46c38b4e05fdbfe407c2
#   experiment_tag: 8_lr=0.001,momentum=0.9
#   hostname: DWAnyscaleMBP.local
#   iterations_since_restore: 1
#   mean_accuracy: 0.146875
#   node_ip: 192.168.1.149
#   pid: 25242
#   time_since_restore: 0.39344215393066406
#   time_this_iter_s: 0.39344215393066406
#   time_total_s: 1.0326793193817139
#   timestamp: 1595170919
#   timesteps_since_restore: 0
#   training_iteration: 4
#   trial_id: c6437144
# == Status ==<br>Memory usage on this node: 10.4/16.0 GiB<br>Using HyperBand: num_stopped=0 total_brackets=2
# Round #0:
#   None
#   Bracket(Max Size (n)=20, Milestone (r)=12, completed=9.8%): {PAUSED: 8, RUNNING: 4} <br>Resources requested: 4/8 CPUs, 0/0 GPUs, 0.0/4.59 GiB heap, 0.0/1.56 GiB objects<br>Result logdir: /Users/deanwampler/ray_results/TrainMNIST<br>Number of trials: 12 (8 PAUSED, 4 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name         </th><th>status  </th><th>loc  </th><th style="text-align: right;">   lr</th><th style="text-align: right;">  momentum</th><th style="text-align: right;">     acc</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th></tr>
# </thead>
# <tbody>
# <tr><td>TrainMNIST_c4a1a4b4</td><td>PAUSED  </td><td>     </td><td style="text-align: right;">0.01 </td><td style="text-align: right;">     0.001</td><td style="text-align: right;">0.46875 </td><td style="text-align: right;">    12</td><td style="text-align: right;">        4.40749 </td></tr>
# <tr><td>TrainMNIST_c4a1ce80</td><td>PAUSED  </td><td>     </td><td style="text-align: right;">0.1  </td><td style="text-align: right;">     0.01 </td><td style="text-align: right;">0.9     </td><td style="text-align: right;">    12</td><td style="text-align: right;">        4.46602 </td></tr>
# <tr><td>TrainMNIST_c4a1ef6e</td><td>PAUSED  </td><td>     </td><td style="text-align: right;">0.001</td><td style="text-align: right;">     0.01 </td><td style="text-align: right;">0.215625</td><td style="text-align: right;">    12</td><td style="text-align: right;">        4.45656 </td></tr>
# <tr><td>TrainMNIST_c4a2102a</td><td>PAUSED  </td><td>     </td><td style="text-align: right;">0.01 </td><td style="text-align: right;">     0.9  </td><td style="text-align: right;">0.790625</td><td style="text-align: right;">    12</td><td style="text-align: right;">        4.85826 </td></tr>
# <tr><td>TrainMNIST_c5ab82b2</td><td>PAUSED  </td><td>     </td><td style="text-align: right;">0.01 </td><td style="text-align: right;">     0.001</td><td style="text-align: right;">0.646875</td><td style="text-align: right;">    12</td><td style="text-align: right;">        4.52849 </td></tr>
# <tr><td>TrainMNIST_c5b631e4</td><td>PAUSED  </td><td>     </td><td style="text-align: right;">0.1  </td><td style="text-align: right;">     0.01 </td><td style="text-align: right;">0.7625  </td><td style="text-align: right;">    12</td><td style="text-align: right;">        4.47754 </td></tr>
# <tr><td>TrainMNIST_c5c661f4</td><td>PAUSED  </td><td>     </td><td style="text-align: right;">0.001</td><td style="text-align: right;">     0.1  </td><td style="text-align: right;">0.15    </td><td style="text-align: right;">    12</td><td style="text-align: right;">        4.50463 </td></tr>
# <tr><td>TrainMNIST_c6437144</td><td>PAUSED  </td><td>     </td><td style="text-align: right;">0.001</td><td style="text-align: right;">     0.9  </td><td style="text-align: right;">0.2     </td><td style="text-align: right;">    12</td><td style="text-align: right;">        4.40513 </td></tr>
# <tr><td>TrainMNIST_c787ca1e</td><td>RUNNING </td><td>     </td><td style="text-align: right;">0.01 </td><td style="text-align: right;">     0.1  </td><td style="text-align: right;">0.19375 </td><td style="text-align: right;">     3</td><td style="text-align: right;">        0.755553</td></tr>
# <tr><td>TrainMNIST_c7946260</td><td>RUNNING </td><td>     </td><td style="text-align: right;">0.001</td><td style="text-align: right;">     0.001</td><td style="text-align: right;">0.05    </td><td style="text-align: right;">     3</td><td style="text-align: right;">        0.729817</td></tr>
# <tr><td>TrainMNIST_c7a21fd6</td><td>RUNNING </td><td>     </td><td style="text-align: right;">0.1  </td><td style="text-align: right;">     0.1  </td><td style="text-align: right;">0.75    </td><td style="text-align: right;">     3</td><td style="text-align: right;">        0.721295</td></tr>
# <tr><td>TrainMNIST_c7aeb8a4</td><td>RUNNING </td><td>     </td><td style="text-align: right;">0.01 </td><td style="text-align: right;">     0.01 </td><td style="text-align: right;">0.234375</td><td style="text-align: right;">     3</td><td style="text-align: right;">        0.722653</td></tr>
# </tbody>
# </table><br><br>
# (pid=25253) 2020-07-19 08:02:03,669	INFO trainable.py:423 -- Restored on 192.168.1.149 from checkpoint: /Users/deanwampler/ray_results/TrainMNIST/TrainMNIST_9_lr=0.01,momentum=0.1_2020-07-19_08-01-52431ftvft/tmphtjpexkurestore_from_object/checkpoint
# (pid=25253) 2020-07-19 08:02:03,669	INFO trainable.py:430 -- Current state after restoring: {'_iteration': 3, '_timesteps_total': None, '_time_total': 0.7555532455444336, '_episodes_total': None}
# (pid=25250) 2020-07-19 08:02:03,705	INFO trainable.py:423 -- Restored on 192.168.1.149 from checkpoint: /Users/deanwampler/ray_results/TrainMNIST/TrainMNIST_10_lr=0.001,momentum=0.001_2020-07-19_08-01-52l0ihd_lv/tmp7xunz8hgrestore_from_object/checkpoint
# (pid=25250) 2020-07-19 08:02:03,705	INFO trainable.py:430 -- Current state after restoring: {'_iteration': 3, '_timesteps_total': None, '_time_total': 0.7298171520233154, '_episodes_total': None}
# (pid=25248) 2020-07-19 08:02:03,773	INFO trainable.py:423 -- Restored on 192.168.1.149 from checkpoint: /Users/deanwampler/ray_results/TrainMNIST/TrainMNIST_11_lr=0.1,momentum=0.1_2020-07-19_08-01-52vy8bwg41/tmpy69r_byirestore_from_object/checkpoint
# (pid=25248) 2020-07-19 08:02:03,773	INFO trainable.py:430 -- Current state after restoring: {'_iteration': 3, '_timesteps_total': None, '_time_total': 0.7212951183319092, '_episodes_total': None}
# Result for TrainMNIST_c787ca1e:
#   date: 2020-07-19_08-02-03
#   done: false
#   experiment_id: 11fbaaf6b8c74dde897cc48662ce07c9
#   experiment_tag: 9_lr=0.01,momentum=0.1
#   hostname: DWAnyscaleMBP.local
#   iterations_since_restore: 1
#   mean_accuracy: 0.1875
#   node_ip: 192.168.1.149
#   pid: 25253
#   time_since_restore: 0.24906492233276367
#   time_this_iter_s: 0.24906492233276367
#   time_total_s: 1.0046181678771973
#   timestamp: 1595170923
#   timesteps_since_restore: 0
#   training_iteration: 4
#   trial_id: c787ca1e
#
# Result for TrainMNIST_c7946260:
#   date: 2020-07-19_08-02-03
#   done: false
#   experiment_id: c56eadbdb27d4e3c8b8e5974716448fa
#   experiment_tag: 10_lr=0.001,momentum=0.001
#   hostname: DWAnyscaleMBP.local
#   iterations_since_restore: 1
#   mean_accuracy: 0.1125
#   node_ip: 192.168.1.149
#   pid: 25250
#   time_since_restore: 0.2565000057220459
#   time_this_iter_s: 0.2565000057220459
#   time_total_s: 0.9863171577453613
#   timestamp: 1595170923
#   timesteps_since_restore: 0
#   training_iteration: 4
#   trial_id: c7946260
#
# Result for TrainMNIST_c7a21fd6:
#   date: 2020-07-19_08-02-04
#   done: false
#   experiment_id: e0685c211e29497992e5561881efbc6b
#   experiment_tag: 11_lr=0.1,momentum=0.1
#   hostname: DWAnyscaleMBP.local
#   iterations_since_restore: 1
#   mean_accuracy: 0.421875
#   node_ip: 192.168.1.149
#   pid: 25248
#   time_since_restore: 0.2633941173553467
#   time_this_iter_s: 0.2633941173553467
#   time_total_s: 0.9846892356872559
#   timestamp: 1595170924
#   timesteps_since_restore: 0
#   training_iteration: 4
#   trial_id: c7a21fd6
#
# (pid=25249) 2020-07-19 08:02:04,385	INFO trainable.py:423 -- Restored on 192.168.1.149 from checkpoint: /Users/deanwampler/ray_results/TrainMNIST/TrainMNIST_12_lr=0.01,momentum=0.01_2020-07-19_08-01-52ljc3dbjw/tmp_ebsno8srestore_from_object/checkpoint
# (pid=25249) 2020-07-19 08:02:04,385	INFO trainable.py:430 -- Current state after restoring: {'_iteration': 3, '_timesteps_total': None, '_time_total': 0.7226529121398926, '_episodes_total': None}
# Result for TrainMNIST_c7aeb8a4:
#   date: 2020-07-19_08-02-04
#   done: false
#   experiment_id: dc24002a5fd74f2c8a9651114b17d102
#   experiment_tag: 12_lr=0.01,momentum=0.01
#   hostname: DWAnyscaleMBP.local
#   iterations_since_restore: 1
#   mean_accuracy: 0.084375
#   node_ip: 192.168.1.149
#   pid: 25249
#   time_since_restore: 0.22896504402160645
#   time_this_iter_s: 0.22896504402160645
#   time_total_s: 0.951617956161499
#   timestamp: 1595170924
#   timesteps_since_restore: 0
#   training_iteration: 4
#   trial_id: c7aeb8a4
#
# (pid=25256) 2020-07-19 08:02:07,720	INFO trainable.py:423 -- Restored on 192.168.1.149 from checkpoint: /Users/deanwampler/ray_results/TrainMNIST/TrainMNIST_2_lr=0.1,momentum=0.01_2020-07-19_08-01-47e02oa8w0/tmp1q1g2vifrestore_from_object/checkpoint
# (pid=25256) 2020-07-19 08:02:07,720	INFO trainable.py:430 -- Current state after restoring: {'_iteration': 12, '_timesteps_total': None, '_time_total': 4.466022729873657, '_episodes_total': None}
# (pid=25251) 2020-07-19 08:02:07,776	INFO trainable.py:423 -- Restored on 192.168.1.149 from checkpoint: /Users/deanwampler/ray_results/TrainMNIST/TrainMNIST_6_lr=0.1,momentum=0.01_2020-07-19_08-01-49azho76dy/tmpe62gwgp5restore_from_object/checkpoint
# (pid=25251) 2020-07-19 08:02:07,776	INFO trainable.py:430 -- Current state after restoring: {'_iteration': 12, '_timesteps_total': None, '_time_total': 4.47754168510437, '_episodes_total': None}
# (pid=25252) 2020-07-19 08:02:07,842	INFO trainable.py:423 -- Restored on 192.168.1.149 from checkpoint: /Users/deanwampler/ray_results/TrainMNIST/TrainMNIST_4_lr=0.01,momentum=0.9_2020-07-19_08-01-47anfhm8wd/tmpgdfh22snrestore_from_object/checkpoint
# (pid=25252) 2020-07-19 08:02:07,842	INFO trainable.py:430 -- Current state after restoring: {'_iteration': 12, '_timesteps_total': None, '_time_total': 4.8582611083984375, '_episodes_total': None}
# Result for TrainMNIST_c4a1ce80:
#   date: 2020-07-19_08-02-08
#   done: false
#   experiment_id: c132d028028c4b3cb198d349abc182ef
#   experiment_tag: 2_lr=0.1,momentum=0.01
#   hostname: DWAnyscaleMBP.local
#   iterations_since_restore: 1
#   mean_accuracy: 0.46875
#   node_ip: 192.168.1.149
#   pid: 25256
#   time_since_restore: 0.31746673583984375
#   time_this_iter_s: 0.31746673583984375
#   time_total_s: 4.783489465713501
#   timestamp: 1595170928
#   timesteps_since_restore: 0
#   training_iteration: 13
#   trial_id: c4a1ce80
#
# Result for TrainMNIST_c5b631e4:
#   date: 2020-07-19_08-02-08
#   done: false
#   experiment_id: 88c2f848b44b414b867431e2888bb8a4
#   experiment_tag: 6_lr=0.1,momentum=0.01
#   hostname: DWAnyscaleMBP.local
#   iterations_since_restore: 1
#   mean_accuracy: 0.56875
#   node_ip: 192.168.1.149
#   pid: 25251
#   time_since_restore: 0.37781381607055664
#   time_this_iter_s: 0.37781381607055664
#   time_total_s: 4.855355501174927
#   timestamp: 1595170928
#   timesteps_since_restore: 0
#   training_iteration: 13
#   trial_id: c5b631e4
#
# Result for TrainMNIST_c4a2102a:
#   date: 2020-07-19_08-02-08
#   done: false
#   experiment_id: 98333a4fe4bc4e7fb492a3bd604acab5
#   experiment_tag: 4_lr=0.01,momentum=0.9
#   hostname: DWAnyscaleMBP.local
#   iterations_since_restore: 1
#   mean_accuracy: 0.121875
#   node_ip: 192.168.1.149
#   pid: 25252
#   time_since_restore: 0.32854676246643066
#   time_this_iter_s: 0.32854676246643066
#   time_total_s: 5.186807870864868
#   timestamp: 1595170928
#   timesteps_since_restore: 0
#   training_iteration: 13
#   trial_id: c4a2102a
# == Status ==<br>Memory usage on this node: 10.3/16.0 GiB<br>Using HyperBand: num_stopped=7 total_brackets=2
# Round #0:
#   None
#   Bracket(Max Size (n)=5, Milestone (r)=48, completed=13.4%): {RUNNING: 5, TERMINATED: 7} <br>Resources requested: 5/8 CPUs, 0/0 GPUs, 0.0/4.59 GiB heap, 0.0/1.56 GiB objects<br>Result logdir: /Users/deanwampler/ray_results/TrainMNIST<br>Number of trials: 12 (5 RUNNING, 7 TERMINATED)<br><table>
# <thead>
# <tr><th>Trial name         </th><th>status    </th><th>loc                </th><th style="text-align: right;">   lr</th><th style="text-align: right;">  momentum</th><th style="text-align: right;">     acc</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th></tr>
# </thead>
# <tbody>
# <tr><td>TrainMNIST_c4a1a4b4</td><td>TERMINATED</td><td>                   </td><td style="text-align: right;">0.01 </td><td style="text-align: right;">     0.001</td><td style="text-align: right;">0.46875 </td><td style="text-align: right;">    12</td><td style="text-align: right;">         4.40749</td></tr>
# <tr><td>TrainMNIST_c4a1ce80</td><td>RUNNING   </td><td>192.168.1.149:25256</td><td style="text-align: right;">0.1  </td><td style="text-align: right;">     0.01 </td><td style="text-align: right;">0.66875 </td><td style="text-align: right;">    14</td><td style="text-align: right;">         5.07019</td></tr>
# <tr><td>TrainMNIST_c4a1ef6e</td><td>TERMINATED</td><td>                   </td><td style="text-align: right;">0.001</td><td style="text-align: right;">     0.01 </td><td style="text-align: right;">0.215625</td><td style="text-align: right;">    12</td><td style="text-align: right;">         4.45656</td></tr>
# <tr><td>TrainMNIST_c4a2102a</td><td>RUNNING   </td><td>192.168.1.149:25252</td><td style="text-align: right;">0.01 </td><td style="text-align: right;">     0.9  </td><td style="text-align: right;">0.121875</td><td style="text-align: right;">    13</td><td style="text-align: right;">         5.18681</td></tr>
# <tr><td>TrainMNIST_c5ab82b2</td><td>TERMINATED</td><td>                   </td><td style="text-align: right;">0.01 </td><td style="text-align: right;">     0.001</td><td style="text-align: right;">0.646875</td><td style="text-align: right;">    12</td><td style="text-align: right;">         4.52849</td></tr>
# <tr><td>TrainMNIST_c5b631e4</td><td>RUNNING   </td><td>192.168.1.149:25251</td><td style="text-align: right;">0.1  </td><td style="text-align: right;">     0.01 </td><td style="text-align: right;">0.56875 </td><td style="text-align: right;">    13</td><td style="text-align: right;">         4.85536</td></tr>
# <tr><td>TrainMNIST_c5c661f4</td><td>TERMINATED</td><td>                   </td><td style="text-align: right;">0.001</td><td style="text-align: right;">     0.1  </td><td style="text-align: right;">0.15    </td><td style="text-align: right;">    12</td><td style="text-align: right;">         4.50463</td></tr>
# <tr><td>TrainMNIST_c6437144</td><td>TERMINATED</td><td>                   </td><td style="text-align: right;">0.001</td><td style="text-align: right;">     0.9  </td><td style="text-align: right;">0.2     </td><td style="text-align: right;">    12</td><td style="text-align: right;">         4.40513</td></tr>
# <tr><td>TrainMNIST_c787ca1e</td><td>TERMINATED</td><td>                   </td><td style="text-align: right;">0.01 </td><td style="text-align: right;">     0.1  </td><td style="text-align: right;">0.6875  </td><td style="text-align: right;">    12</td><td style="text-align: right;">         2.84579</td></tr>
# <tr><td>TrainMNIST_c7946260</td><td>TERMINATED</td><td>                   </td><td style="text-align: right;">0.001</td><td style="text-align: right;">     0.001</td><td style="text-align: right;">0.13125 </td><td style="text-align: right;">    12</td><td style="text-align: right;">         2.81379</td></tr>
# <tr><td>TrainMNIST_c7a21fd6</td><td>RUNNING   </td><td>                   </td><td style="text-align: right;">0.1  </td><td style="text-align: right;">     0.1  </td><td style="text-align: right;">0.88125 </td><td style="text-align: right;">    12</td><td style="text-align: right;">         2.80706</td></tr>
# <tr><td>TrainMNIST_c7aeb8a4</td><td>RUNNING   </td><td>                   </td><td style="text-align: right;">0.01 </td><td style="text-align: right;">     0.01 </td><td style="text-align: right;">0.690625</td><td style="text-align: right;">    12</td><td style="text-align: right;">         2.72304</td></tr>
# </tbody>
# </table><br><br>
# (pid=25281) 2020-07-19 08:02:08,668	INFO trainable.py:423 -- Restored on 192.168.1.149 from checkpoint: /Users/deanwampler/ray_results/TrainMNIST/TrainMNIST_11_lr=0.1,momentum=0.1_2020-07-19_08-01-52vy8bwg41/tmp8pbv78fcrestore_from_object/checkpoint
# (pid=25281) 2020-07-19 08:02:08,668	INFO trainable.py:430 -- Current state after restoring: {'_iteration': 12, '_timesteps_total': None, '_time_total': 2.8070592880249023, '_episodes_total': None}
# (pid=25278) 2020-07-19 08:02:08,751	INFO trainable.py:423 -- Restored on 192.168.1.149 from checkpoint: /Users/deanwampler/ray_results/TrainMNIST/TrainMNIST_12_lr=0.01,momentum=0.01_2020-07-19_08-01-52ljc3dbjw/tmp___4vhherestore_from_object/checkpoint
# (pid=25278) 2020-07-19 08:02:08,751	INFO trainable.py:430 -- Current state after restoring: {'_iteration': 12, '_timesteps_total': None, '_time_total': 2.723043203353882, '_episodes_total': None}
# Result for TrainMNIST_c7a21fd6:
#   date: 2020-07-19_08-02-09
#   done: false
#   experiment_id: e0685c211e29497992e5561881efbc6b
#   experiment_tag: 11_lr=0.1,momentum=0.1
#   hostname: DWAnyscaleMBP.local
#   iterations_since_restore: 2
#   mean_accuracy: 0.609375
#   node_ip: 192.168.1.149
#   pid: 25281
#   time_since_restore: 0.5478999614715576
#   time_this_iter_s: 0.2650940418243408
#   time_total_s: 3.35495924949646
#   timestamp: 1595170929
#   timesteps_since_restore: 0
#   training_iteration: 14
#   trial_id: c7a21fd6
#
# Result for TrainMNIST_c7aeb8a4:
#   date: 2020-07-19_08-02-09
#   done: false
#   experiment_id: dc24002a5fd74f2c8a9651114b17d102
#   experiment_tag: 12_lr=0.01,momentum=0.01
#   hostname: DWAnyscaleMBP.local
#   iterations_since_restore: 3
#   mean_accuracy: 0.159375
#   node_ip: 192.168.1.149
#   pid: 25278
#   time_since_restore: 0.88326096534729
#   time_this_iter_s: 0.30037403106689453
#   time_total_s: 3.606304168701172
#   timestamp: 1595170929
#   timesteps_since_restore: 0
#   training_iteration: 15
#   trial_id: c7aeb8a4
#
# Result for TrainMNIST_c4a1ce80:
#   date: 2020-07-19_08-02-13
#   done: false
#   experiment_id: c132d028028c4b3cb198d349abc182ef
#   experiment_tag: 2_lr=0.1,momentum=0.01
#   hostname: DWAnyscaleMBP.local
#   iterations_since_restore: 19
#   mean_accuracy: 0.90625
#   node_ip: 192.168.1.149
#   pid: 25256
#   time_since_restore: 5.3515400886535645
#   time_this_iter_s: 0.3235776424407959
#   time_total_s: 9.817562818527222
#   timestamp: 1595170933
#   timesteps_since_restore: 0
#   training_iteration: 31
#   trial_id: c4a1ce80
#
# Result for TrainMNIST_c4a2102a:
#   date: 2020-07-19_08-02-13
#   done: false
#   experiment_id: 98333a4fe4bc4e7fb492a3bd604acab5
#   experiment_tag: 4_lr=0.01,momentum=0.9
#   hostname: DWAnyscaleMBP.local
#   iterations_since_restore: 19
#   mean_accuracy: 0.60625
#   node_ip: 192.168.1.149
#   pid: 25252
#   time_since_restore: 5.331586122512817
#   time_this_iter_s: 0.3087899684906006
#   time_total_s: 10.189847230911255
#   timestamp: 1595170933
#   timesteps_since_restore: 0
#   training_iteration: 31
#   trial_id: c4a2102a
#
# Result for TrainMNIST_c5b631e4:
#   date: 2020-07-19_08-02-13
#   done: false
#   experiment_id: 88c2f848b44b414b867431e2888bb8a4
#   experiment_tag: 6_lr=0.1,momentum=0.01
#   hostname: DWAnyscaleMBP.local
#   iterations_since_restore: 19
#   mean_accuracy: 0.88125
#   node_ip: 192.168.1.149
#   pid: 25251
#   time_since_restore: 5.402474641799927
#   time_this_iter_s: 0.30208706855773926
#   time_total_s: 9.880016326904297
#   timestamp: 1595170933
#   timesteps_since_restore: 0
#   training_iteration: 31
#   trial_id: c5b631e4
# == Status ==<br>Memory usage on this node: 10.4/16.0 GiB<br>Using HyperBand: num_stopped=7 total_brackets=2
# Round #0:
#   None
#   Bracket(Max Size (n)=5, Milestone (r)=48, completed=21.1%): {RUNNING: 5, TERMINATED: 7} <br>Resources requested: 5/8 CPUs, 0/0 GPUs, 0.0/4.59 GiB heap, 0.0/1.56 GiB objects<br>Result logdir: /Users/deanwampler/ray_results/TrainMNIST<br>Number of trials: 12 (5 RUNNING, 7 TERMINATED)<br><table>
# <thead>
# <tr><th>Trial name         </th><th>status    </th><th>loc                </th><th style="text-align: right;">   lr</th><th style="text-align: right;">  momentum</th><th style="text-align: right;">     acc</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th></tr>
# </thead>
# <tbody>
# <tr><td>TrainMNIST_c4a1a4b4</td><td>TERMINATED</td><td>                   </td><td style="text-align: right;">0.01 </td><td style="text-align: right;">     0.001</td><td style="text-align: right;">0.46875 </td><td style="text-align: right;">    12</td><td style="text-align: right;">         4.40749</td></tr>
# <tr><td>TrainMNIST_c4a1ce80</td><td>RUNNING   </td><td>192.168.1.149:25256</td><td style="text-align: right;">0.1  </td><td style="text-align: right;">     0.01 </td><td style="text-align: right;">0.90625 </td><td style="text-align: right;">    31</td><td style="text-align: right;">         9.81756</td></tr>
# <tr><td>TrainMNIST_c4a1ef6e</td><td>TERMINATED</td><td>                   </td><td style="text-align: right;">0.001</td><td style="text-align: right;">     0.01 </td><td style="text-align: right;">0.215625</td><td style="text-align: right;">    12</td><td style="text-align: right;">         4.45656</td></tr>
# <tr><td>TrainMNIST_c4a2102a</td><td>RUNNING   </td><td>192.168.1.149:25252</td><td style="text-align: right;">0.01 </td><td style="text-align: right;">     0.9  </td><td style="text-align: right;">0.60625 </td><td style="text-align: right;">    31</td><td style="text-align: right;">        10.1898 </td></tr>
# <tr><td>TrainMNIST_c5ab82b2</td><td>TERMINATED</td><td>                   </td><td style="text-align: right;">0.01 </td><td style="text-align: right;">     0.001</td><td style="text-align: right;">0.646875</td><td style="text-align: right;">    12</td><td style="text-align: right;">         4.52849</td></tr>
# <tr><td>TrainMNIST_c5b631e4</td><td>RUNNING   </td><td>192.168.1.149:25251</td><td style="text-align: right;">0.1  </td><td style="text-align: right;">     0.01 </td><td style="text-align: right;">0.88125 </td><td style="text-align: right;">    31</td><td style="text-align: right;">         9.88002</td></tr>
# <tr><td>TrainMNIST_c5c661f4</td><td>TERMINATED</td><td>                   </td><td style="text-align: right;">0.001</td><td style="text-align: right;">     0.1  </td><td style="text-align: right;">0.15    </td><td style="text-align: right;">    12</td><td style="text-align: right;">         4.50463</td></tr>
# <tr><td>TrainMNIST_c6437144</td><td>TERMINATED</td><td>                   </td><td style="text-align: right;">0.001</td><td style="text-align: right;">     0.9  </td><td style="text-align: right;">0.2     </td><td style="text-align: right;">    12</td><td style="text-align: right;">         4.40513</td></tr>
# <tr><td>TrainMNIST_c787ca1e</td><td>TERMINATED</td><td>                   </td><td style="text-align: right;">0.01 </td><td style="text-align: right;">     0.1  </td><td style="text-align: right;">0.6875  </td><td style="text-align: right;">    12</td><td style="text-align: right;">         2.84579</td></tr>
# <tr><td>TrainMNIST_c7946260</td><td>TERMINATED</td><td>                   </td><td style="text-align: right;">0.001</td><td style="text-align: right;">     0.001</td><td style="text-align: right;">0.13125 </td><td style="text-align: right;">    12</td><td style="text-align: right;">         2.81379</td></tr>
# <tr><td>TrainMNIST_c7a21fd6</td><td>RUNNING   </td><td>192.168.1.149:25281</td><td style="text-align: right;">0.1  </td><td style="text-align: right;">     0.1  </td><td style="text-align: right;">0.934375</td><td style="text-align: right;">    28</td><td style="text-align: right;">         7.28522</td></tr>
# <tr><td>TrainMNIST_c7aeb8a4</td><td>RUNNING   </td><td>192.168.1.149:25278</td><td style="text-align: right;">0.01 </td><td style="text-align: right;">     0.01 </td><td style="text-align: right;">0.75    </td><td style="text-align: right;">    28</td><td style="text-align: right;">         7.30524</td></tr>
# </tbody>
# </table><br><br>
# Result for TrainMNIST_c7a21fd6:
#   date: 2020-07-19_08-02-14
#   done: false
#   experiment_id: e0685c211e29497992e5561881efbc6b
#   experiment_tag: 11_lr=0.1,momentum=0.1
#   hostname: DWAnyscaleMBP.local
#   iterations_since_restore: 20
#   mean_accuracy: 0.95
#   node_ip: 192.168.1.149
#   pid: 25281
#   time_since_restore: 5.565382957458496
#   time_this_iter_s: 0.2779850959777832
#   time_total_s: 8.372442245483398
#   timestamp: 1595170934
#   timesteps_since_restore: 0
#   training_iteration: 32
#   trial_id: c7a21fd6
#
# ...
# </tbody>
# </table><br><br>
# Result for TrainMNIST_c5b631e4:
#   date: 2020-07-19_08-02-30
#   done: false
#   experiment_id: 88c2f848b44b414b867431e2888bb8a4
#   experiment_tag: 6_lr=0.1,momentum=0.01
#   hostname: DWAnyscaleMBP.local
#   iterations_since_restore: 54
#   mean_accuracy: 0.93125
#   node_ip: 192.168.1.149
#   pid: 25282
#   time_since_restore: 10.255598783493042
#   time_this_iter_s: 0.1824951171875
#   time_total_s: 24.803852081298828
#   timestamp: 1595170950
#   timesteps_since_restore: 0
#   training_iteration: 102
#   trial_id: c5b631e4
#
# Result for TrainMNIST_c7a21fd6:
#   date: 2020-07-19_08-02-30
#   done: false
#   experiment_id: e0685c211e29497992e5561881efbc6b
#   experiment_tag: 11_lr=0.1,momentum=0.1
#   hostname: DWAnyscaleMBP.local
#   iterations_since_restore: 53
#   mean_accuracy: 0.93125
#   node_ip: 192.168.1.149
#   pid: 25290
#   time_since_restore: 10.26732087135315
#   time_this_iter_s: 0.17782998085021973
#   time_total_s: 22.922979593276978
#   timestamp: 1595170950
#   timesteps_since_restore: 0
#   training_iteration: 101
#   trial_id: c7a21fd6
# == Status ==<br>Memory usage on this node: 10.5/16.0 GiB<br>Using HyperBand: num_stopped=10 total_brackets=2
# Round #0:
#   None
#   Bracket(Max Size (n)=2, Milestone (r)=152, completed=41.9%): {RUNNING: 2, TERMINATED: 10} <br>Resources requested: 2/8 CPUs, 0/0 GPUs, 0.0/4.59 GiB heap, 0.0/1.56 GiB objects<br>Result logdir: /Users/deanwampler/ray_results/TrainMNIST<br>Number of trials: 12 (2 RUNNING, 10 TERMINATED)<br><table>
# <thead>
# <tr><th>Trial name         </th><th>status    </th><th>loc                </th><th style="text-align: right;">   lr</th><th style="text-align: right;">  momentum</th><th style="text-align: right;">     acc</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th></tr>
# </thead>
# <tbody>
# <tr><td>TrainMNIST_c4a1a4b4</td><td>TERMINATED</td><td>                   </td><td style="text-align: right;">0.01 </td><td style="text-align: right;">     0.001</td><td style="text-align: right;">0.46875 </td><td style="text-align: right;">    12</td><td style="text-align: right;">         4.40749</td></tr>
# <tr><td>TrainMNIST_c4a1ce80</td><td>TERMINATED</td><td>                   </td><td style="text-align: right;">0.1  </td><td style="text-align: right;">     0.01 </td><td style="text-align: right;">0.921875</td><td style="text-align: right;">    48</td><td style="text-align: right;">        14.5216 </td></tr>
# <tr><td>TrainMNIST_c4a1ef6e</td><td>TERMINATED</td><td>                   </td><td style="text-align: right;">0.001</td><td style="text-align: right;">     0.01 </td><td style="text-align: right;">0.215625</td><td style="text-align: right;">    12</td><td style="text-align: right;">         4.45656</td></tr>
# <tr><td>TrainMNIST_c4a2102a</td><td>TERMINATED</td><td>                   </td><td style="text-align: right;">0.01 </td><td style="text-align: right;">     0.9  </td><td style="text-align: right;">0.871875</td><td style="text-align: right;">    48</td><td style="text-align: right;">        14.8339 </td></tr>
# <tr><td>TrainMNIST_c5ab82b2</td><td>TERMINATED</td><td>                   </td><td style="text-align: right;">0.01 </td><td style="text-align: right;">     0.001</td><td style="text-align: right;">0.646875</td><td style="text-align: right;">    12</td><td style="text-align: right;">         4.52849</td></tr>
# <tr><td>TrainMNIST_c5b631e4</td><td>RUNNING   </td><td>192.168.1.149:25282</td><td style="text-align: right;">0.1  </td><td style="text-align: right;">     0.01 </td><td style="text-align: right;">0.940625</td><td style="text-align: right;">   120</td><td style="text-align: right;">        28.2245 </td></tr>
# <tr><td>TrainMNIST_c5c661f4</td><td>TERMINATED</td><td>                   </td><td style="text-align: right;">0.001</td><td style="text-align: right;">     0.1  </td><td style="text-align: right;">0.15    </td><td style="text-align: right;">    12</td><td style="text-align: right;">         4.50463</td></tr>
# <tr><td>TrainMNIST_c6437144</td><td>TERMINATED</td><td>                   </td><td style="text-align: right;">0.001</td><td style="text-align: right;">     0.9  </td><td style="text-align: right;">0.2     </td><td style="text-align: right;">    12</td><td style="text-align: right;">         4.40513</td></tr>
# <tr><td>TrainMNIST_c787ca1e</td><td>TERMINATED</td><td>                   </td><td style="text-align: right;">0.01 </td><td style="text-align: right;">     0.1  </td><td style="text-align: right;">0.6875  </td><td style="text-align: right;">    12</td><td style="text-align: right;">         2.84579</td></tr>
# <tr><td>TrainMNIST_c7946260</td><td>TERMINATED</td><td>                   </td><td style="text-align: right;">0.001</td><td style="text-align: right;">     0.001</td><td style="text-align: right;">0.13125 </td><td style="text-align: right;">    12</td><td style="text-align: right;">         2.81379</td></tr>
# <tr><td>TrainMNIST_c7a21fd6</td><td>RUNNING   </td><td>192.168.1.149:25290</td><td style="text-align: right;">0.1  </td><td style="text-align: right;">     0.1  </td><td style="text-align: right;">0.946875</td><td style="text-align: right;">   115</td><td style="text-align: right;">        25.6497 </td></tr>
# <tr><td>TrainMNIST_c7aeb8a4</td><td>TERMINATED</td><td>                   </td><td style="text-align: right;">0.01 </td><td style="text-align: right;">     0.01 </td><td style="text-align: right;">0.8625  </td><td style="text-align: right;">    48</td><td style="text-align: right;">        12.644  </td></tr>
# </tbody>
# </table><br><br>
# Result for TrainMNIST_c5b631e4:
#   date: 2020-07-19_08-02-35
#   done: false
#   experiment_id: 88c2f848b44b414b867431e2888bb8a4
#   experiment_tag: 6_lr=0.1,momentum=0.01
#   hostname: DWAnyscaleMBP.local
#   iterations_since_restore: 80
#   mean_accuracy: 0.95
#   node_ip: 192.168.1.149
#   pid: 25282
#   time_since_restore: 15.301830530166626
#   time_this_iter_s: 0.2082371711730957
#   time_total_s: 29.850083827972412
#   timestamp: 1595170955
#   timesteps_since_restore: 0
#   training_iteration: 128
#   trial_id: c5b631e4
#
# Result for TrainMNIST_c7a21fd6:
#   date: 2020-07-19_08-02-35
#   done: false
#   experiment_id: e0685c211e29497992e5561881efbc6b
#   experiment_tag: 11_lr=0.1,momentum=0.1
#   hostname: DWAnyscaleMBP.local
#   iterations_since_restore: 78
#   mean_accuracy: 0.95
#   node_ip: 192.168.1.149
#   pid: 25290
#   time_since_restore: 15.256131410598755
#   time_this_iter_s: 0.2039790153503418
#   time_total_s: 27.911790132522583
#   timestamp: 1595170955
#   timesteps_since_restore: 0
#   training_iteration: 126
#   trial_id: c7a21fd6
# == Status ==<br>Memory usage on this node: 10.5/16.0 GiB<br>Using HyperBand: num_stopped=10 total_brackets=2
# Round #0:
#   None
#   Bracket(Max Size (n)=2, Milestone (r)=152, completed=46.5%): {RUNNING: 2, TERMINATED: 10} <br>Resources requested: 2/8 CPUs, 0/0 GPUs, 0.0/4.59 GiB heap, 0.0/1.56 GiB objects<br>Result logdir: /Users/deanwampler/ray_results/TrainMNIST<br>Number of trials: 12 (2 RUNNING, 10 TERMINATED)<br><table>
# <thead>
# <tr><th>Trial name         </th><th>status    </th><th>loc                </th><th style="text-align: right;">   lr</th><th style="text-align: right;">  momentum</th><th style="text-align: right;">     acc</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th></tr>
# </thead>
# <tbody>
# <tr><td>TrainMNIST_c4a1a4b4</td><td>TERMINATED</td><td>                   </td><td style="text-align: right;">0.01 </td><td style="text-align: right;">     0.001</td><td style="text-align: right;">0.46875 </td><td style="text-align: right;">    12</td><td style="text-align: right;">         4.40749</td></tr>
# <tr><td>TrainMNIST_c4a1ce80</td><td>TERMINATED</td><td>                   </td><td style="text-align: right;">0.1  </td><td style="text-align: right;">     0.01 </td><td style="text-align: right;">0.921875</td><td style="text-align: right;">    48</td><td style="text-align: right;">        14.5216 </td></tr>
# <tr><td>TrainMNIST_c4a1ef6e</td><td>TERMINATED</td><td>                   </td><td style="text-align: right;">0.001</td><td style="text-align: right;">     0.01 </td><td style="text-align: right;">0.215625</td><td style="text-align: right;">    12</td><td style="text-align: right;">         4.45656</td></tr>
# <tr><td>TrainMNIST_c4a2102a</td><td>TERMINATED</td><td>                   </td><td style="text-align: right;">0.01 </td><td style="text-align: right;">     0.9  </td><td style="text-align: right;">0.871875</td><td style="text-align: right;">    48</td><td style="text-align: right;">        14.8339 </td></tr>
# <tr><td>TrainMNIST_c5ab82b2</td><td>TERMINATED</td><td>                   </td><td style="text-align: right;">0.01 </td><td style="text-align: right;">     0.001</td><td style="text-align: right;">0.646875</td><td style="text-align: right;">    12</td><td style="text-align: right;">         4.52849</td></tr>
# <tr><td>TrainMNIST_c5b631e4</td><td>RUNNING   </td><td>192.168.1.149:25282</td><td style="text-align: right;">0.1  </td><td style="text-align: right;">     0.01 </td><td style="text-align: right;">0.934375</td><td style="text-align: right;">   145</td><td style="text-align: right;">        33.2055 </td></tr>
# <tr><td>TrainMNIST_c5c661f4</td><td>TERMINATED</td><td>                   </td><td style="text-align: right;">0.001</td><td style="text-align: right;">     0.1  </td><td style="text-align: right;">0.15    </td><td style="text-align: right;">    12</td><td style="text-align: right;">         4.50463</td></tr>
# <tr><td>TrainMNIST_c6437144</td><td>TERMINATED</td><td>                   </td><td style="text-align: right;">0.001</td><td style="text-align: right;">     0.9  </td><td style="text-align: right;">0.2     </td><td style="text-align: right;">    12</td><td style="text-align: right;">         4.40513</td></tr>
# <tr><td>TrainMNIST_c787ca1e</td><td>TERMINATED</td><td>                   </td><td style="text-align: right;">0.01 </td><td style="text-align: right;">     0.1  </td><td style="text-align: right;">0.6875  </td><td style="text-align: right;">    12</td><td style="text-align: right;">         2.84579</td></tr>
# <tr><td>TrainMNIST_c7946260</td><td>TERMINATED</td><td>                   </td><td style="text-align: right;">0.001</td><td style="text-align: right;">     0.001</td><td style="text-align: right;">0.13125 </td><td style="text-align: right;">    12</td><td style="text-align: right;">         2.81379</td></tr>
# <tr><td>TrainMNIST_c7a21fd6</td><td>RUNNING   </td><td>192.168.1.149:25290</td><td style="text-align: right;">0.1  </td><td style="text-align: right;">     0.1  </td><td style="text-align: right;">0.95    </td><td style="text-align: right;">   140</td><td style="text-align: right;">        30.7481 </td></tr>
# <tr><td>TrainMNIST_c7aeb8a4</td><td>TERMINATED</td><td>                   </td><td style="text-align: right;">0.01 </td><td style="text-align: right;">     0.01 </td><td style="text-align: right;">0.8625  </td><td style="text-align: right;">    48</td><td style="text-align: right;">        12.644  </td></tr>
# </tbody>
# </table><br><br>
# Result for TrainMNIST_c7a21fd6:
#   date: 2020-07-19_08-02-40
#   done: true
#   experiment_id: e0685c211e29497992e5561881efbc6b
#   experiment_tag: 11_lr=0.1,momentum=0.1
#   hostname: DWAnyscaleMBP.local
#   iterations_since_restore: 104
#   mean_accuracy: 0.959375
#   node_ip: 192.168.1.149
#   pid: 25290
#   time_since_restore: 20.302512645721436
#   time_this_iter_s: 0.1692650318145752
#   time_total_s: 32.958171367645264
#   timestamp: 1595170960
#   timesteps_since_restore: 0
#   training_iteration: 152
#   trial_id: c7a21fd6
# == Status ==<br>Memory usage on this node: 10.4/16.0 GiB<br>Using HyperBand: num_stopped=10 total_brackets=2
# Round #0:
#   None
#   Bracket(Max Size (n)=2, Milestone (r)=152, completed=100.0%): {TERMINATED: 12} <br>Resources requested: 0/8 CPUs, 0/0 GPUs, 0.0/4.59 GiB heap, 0.0/1.56 GiB objects<br>Result logdir: /Users/deanwampler/ray_results/TrainMNIST<br>Number of trials: 12 (12 TERMINATED)<br><table>
# <thead>
# <tr><th>Trial name         </th><th>status    </th><th>loc  </th><th style="text-align: right;">   lr</th><th style="text-align: right;">  momentum</th><th style="text-align: right;">     acc</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th></tr>
# </thead>
# <tbody>
# <tr><td>TrainMNIST_c4a1a4b4</td><td>TERMINATED</td><td>     </td><td style="text-align: right;">0.01 </td><td style="text-align: right;">     0.001</td><td style="text-align: right;">0.46875 </td><td style="text-align: right;">    12</td><td style="text-align: right;">         4.40749</td></tr>
# <tr><td>TrainMNIST_c4a1ce80</td><td>TERMINATED</td><td>     </td><td style="text-align: right;">0.1  </td><td style="text-align: right;">     0.01 </td><td style="text-align: right;">0.921875</td><td style="text-align: right;">    48</td><td style="text-align: right;">        14.5216 </td></tr>
# <tr><td>TrainMNIST_c4a1ef6e</td><td>TERMINATED</td><td>     </td><td style="text-align: right;">0.001</td><td style="text-align: right;">     0.01 </td><td style="text-align: right;">0.215625</td><td style="text-align: right;">    12</td><td style="text-align: right;">         4.45656</td></tr>
# <tr><td>TrainMNIST_c4a2102a</td><td>TERMINATED</td><td>     </td><td style="text-align: right;">0.01 </td><td style="text-align: right;">     0.9  </td><td style="text-align: right;">0.871875</td><td style="text-align: right;">    48</td><td style="text-align: right;">        14.8339 </td></tr>
# <tr><td>TrainMNIST_c5ab82b2</td><td>TERMINATED</td><td>     </td><td style="text-align: right;">0.01 </td><td style="text-align: right;">     0.001</td><td style="text-align: right;">0.646875</td><td style="text-align: right;">    12</td><td style="text-align: right;">         4.52849</td></tr>
# <tr><td>TrainMNIST_c5b631e4</td><td>TERMINATED</td><td>     </td><td style="text-align: right;">0.1  </td><td style="text-align: right;">     0.01 </td><td style="text-align: right;">0.953125</td><td style="text-align: right;">   152</td><td style="text-align: right;">        34.5061 </td></tr>
# <tr><td>TrainMNIST_c5c661f4</td><td>TERMINATED</td><td>     </td><td style="text-align: right;">0.001</td><td style="text-align: right;">     0.1  </td><td style="text-align: right;">0.15    </td><td style="text-align: right;">    12</td><td style="text-align: right;">         4.50463</td></tr>
# <tr><td>TrainMNIST_c6437144</td><td>TERMINATED</td><td>     </td><td style="text-align: right;">0.001</td><td style="text-align: right;">     0.9  </td><td style="text-align: right;">0.2     </td><td style="text-align: right;">    12</td><td style="text-align: right;">         4.40513</td></tr>
# <tr><td>TrainMNIST_c787ca1e</td><td>TERMINATED</td><td>     </td><td style="text-align: right;">0.01 </td><td style="text-align: right;">     0.1  </td><td style="text-align: right;">0.6875  </td><td style="text-align: right;">    12</td><td style="text-align: right;">         2.84579</td></tr>
# <tr><td>TrainMNIST_c7946260</td><td>TERMINATED</td><td>     </td><td style="text-align: right;">0.001</td><td style="text-align: right;">     0.001</td><td style="text-align: right;">0.13125 </td><td style="text-align: right;">    12</td><td style="text-align: right;">         2.81379</td></tr>
# <tr><td>TrainMNIST_c7a21fd6</td><td>TERMINATED</td><td>     </td><td style="text-align: right;">0.1  </td><td style="text-align: right;">     0.1  </td><td style="text-align: right;">0.959375</td><td style="text-align: right;">   152</td><td style="text-align: right;">        32.9582 </td></tr>
# <tr><td>TrainMNIST_c7aeb8a4</td><td>TERMINATED</td><td>     </td><td style="text-align: right;">0.01 </td><td style="text-align: right;">     0.01 </td><td style="text-align: right;">0.8625  </td><td style="text-align: right;">    48</td><td style="text-align: right;">        12.644  </td></tr>
# </tbody>
# </table><br><br>

# %%
print("Best config: ", analysis.get_best_config(metric="mean_accuracy"))
# Out:
# Best config:  {'lr': 0.1, 'momentum': 0.01}

# %%
analysis.dataframe().sort_values('mean_accuracy', ascending=False).head()
# Out:
#     mean_accuracy   done  timesteps_total  episodes_total  training_iteration  \
# 10       0.959375   True              NaN             NaN                 152
# 5        0.953125  False              NaN             NaN                 152
# 1        0.921875  False              NaN             NaN                  48
# 3        0.871875  False              NaN             NaN                  48
# 11       0.862500   True              NaN             NaN                  48
#
#                        experiment_id                 date   timestamp  \
# 10  e0685c211e29497992e5561881efbc6b  2020-07-19_08-02-40  1595170960
# 5   88c2f848b44b414b867431e2888bb8a4  2020-07-19_08-02-39  1595170959
# 1   c132d028028c4b3cb198d349abc182ef  2020-07-19_08-02-17  1595170937
# 3   98333a4fe4bc4e7fb492a3bd604acab5  2020-07-19_08-02-17  1595170937
# 11  dc24002a5fd74f2c8a9651114b17d102  2020-07-19_08-02-18  1595170938
#
#     time_this_iter_s  time_total_s  ...             hostname        node_ip  \
# 10          0.169265     32.958171  ...  DWAnyscaleMBP.local  192.168.1.149
# 5           0.183516     34.506141  ...  DWAnyscaleMBP.local  192.168.1.149
# 1           0.273994     14.521615  ...  DWAnyscaleMBP.local  192.168.1.149
# 3           0.265256     14.833880  ...  DWAnyscaleMBP.local  192.168.1.149
# 11          0.200659     12.644042  ...  DWAnyscaleMBP.local  192.168.1.149
#
#    time_since_restore  timesteps_since_restore  iterations_since_restore  \
# 10          20.302513                        0                       104
# 5           19.957888                        0                       104
# 1           10.055592                        0                        36
# 3            9.975619                        0                        36
# 11           9.920999                        0                        36
#
#     trial_id            experiment_tag config/lr  config/momentum  \
# 10  c7a21fd6    11_lr=0.1,momentum=0.1      0.10             0.10
# 5   c5b631e4    6_lr=0.1,momentum=0.01      0.10             0.01
# 1   c4a1ce80    2_lr=0.1,momentum=0.01      0.10             0.01
# 3   c4a2102a    4_lr=0.01,momentum=0.9      0.01             0.90
# 11  c7aeb8a4  12_lr=0.01,momentum=0.01      0.01             0.01
#
#                                                logdir
# 10  /Users/deanwampler/ray_results/TrainMNIST/Trai...
# 5   /Users/deanwampler/ray_results/TrainMNIST/Trai...
# 1   /Users/deanwampler/ray_results/TrainMNIST/Trai...
# 3   /Users/deanwampler/ray_results/TrainMNIST/Trai...
# 11  /Users/deanwampler/ray_results/TrainMNIST/Trai...
#
# [5 rows x 21 columns]

# %%
analysis.dataframe()[['mean_accuracy', 'config/lr', 'config/momentum']].sort_values('mean_accuracy', ascending=False)
# Out:
#     mean_accuracy  config/lr  config/momentum
# 10       0.959375      0.100            0.100
# 5        0.953125      0.100            0.010
# 1        0.921875      0.100            0.010
# 3        0.871875      0.010            0.900
# 11       0.862500      0.010            0.010
# 8        0.687500      0.010            0.100
# 4        0.646875      0.010            0.001
# 0        0.468750      0.010            0.001
# 2        0.215625      0.001            0.010
# 7        0.200000      0.001            0.900
# 6        0.150000      0.001            0.100
# 9        0.131250      0.001            0.001

# %% [markdown]
# How long did it take?

# %%
stats = analysis.stats()
secs = stats["timestamp"] - stats["start_time"]
print(f'{secs:7.2f} seconds, {secs/60.0:7.2f} minutes')
# Out:
#   53.08 seconds,    0.88 minutes

# %% [markdown]
# The runs in the previous lesson, for the class-based and the function-based Tune APIs, took between 12 and 20 seconds (on my machine), but we only trained for 20 iterations, where as here we went for 100 iterations. That also accounts for the different results, notably that a much smaller momentum value `0.01` and `0.1` perform best here, while for the the previous lesson `0.9` performed best. This is because a smaller momentum value will result in longer training times required, but more fine-tuned iterating to the optimal result, so more training iterations will favor a smaller momentum value. Still, the mean accuracies among the top three or four combinations are quite close.

# %% [markdown]
# ## Exercise - Population Base Training
#
# Read the [documentation]() on _population based training_ to understand what it is doing. The next cell configures a PBT scheduler and defines other things you'll need.

# %%
from ray.tune.schedulers import PopulationBasedTraining

pbt_scheduler = PopulationBasedTraining(
        time_attr='training_iteration',
        perturbation_interval=10,  # Every N time_attr units, "perturb" the parameters.
        hyperparam_mutations={
            "lr": [0.001, 0.01, 0.1],
            "momentum": [0.001, 0.01, 0.1, 0.9]
        },
        **experiment_metrics)

config = {
    "lr": 0.001,            # Use the lowest values from the previous definition
    "momentum": 0.001
}
# Out:
# (pid=26711) 2020-07-19 08:43:59,909	INFO trainable.py:423 -- Restored on 192.168.1.149 from checkpoint: /Users/deanwampler/ray_results/TrainMNIST/TrainMNIST_2_2020-07-19_08-33-07vmh5os0q/tmpje8nicoarestore_from_object/checkpoint
# (pid=26711) 2020-07-19 08:43:59,910	INFO trainable.py:430 -- Current state after restoring: {'_iteration': 1290, '_timesteps_total': None, '_time_total': 613.1370136737823, '_episodes_total': None}
# (pid=26715) 2020-07-19 08:44:02,606	INFO trainable.py:423 -- Restored on 192.168.1.149 from checkpoint: /Users/deanwampler/ray_results/TrainMNIST/TrainMNIST_0_2020-07-19_08-33-07uc57ewdo/tmpzups7il9restore_from_object/checkpoint
# (pid=26715) 2020-07-19 08:44:02,606	INFO trainable.py:430 -- Current state after restoring: {'_iteration': 1300, '_timesteps_total': None, '_time_total': 624.1683716773987, '_episodes_total': None}
# (pid=26716) 2020-07-19 08:44:06,818	INFO trainable.py:423 -- Restored on 192.168.1.149 from checkpoint: /Users/deanwampler/ray_results/TrainMNIST/TrainMNIST_2_2020-07-19_08-33-07vmh5os0q/tmpvpz7ybp9restore_from_object/checkpoint
# (pid=26716) 2020-07-19 08:44:06,819	INFO trainable.py:430 -- Current state after restoring: {'_iteration': 1340, '_timesteps_total': None, '_time_total': 636.9976081848145, '_episodes_total': None}
# (pid=26721) 2020-07-19 08:44:10,715	INFO trainable.py:423 -- Restored on 192.168.1.149 from checkpoint: /Users/deanwampler/ray_results/TrainMNIST/TrainMNIST_0_2020-07-19_08-33-07uc57ewdo/tmp2qtvsd5urestore_from_object/checkpoint
# (pid=26721) 2020-07-19 08:44:10,715	INFO trainable.py:430 -- Current state after restoring: {'_iteration': 1340, '_timesteps_total': None, '_time_total': 636.9976081848145, '_episodes_total': None}
# 2020-07-19 08:44:12,385	INFO (unknown file):0 -- gc.collect() freed 16 refs in 0.10996127999987948 seconds
# (pid=26725) 2020-07-19 08:44:14,952	INFO trainable.py:423 -- Restored on 192.168.1.149 from checkpoint: /Users/deanwampler/ray_results/TrainMNIST/TrainMNIST_2_2020-07-19_08-33-07vmh5os0q/tmp5fs3_sbhrestore_from_object/checkpoint
# (pid=26725) 2020-07-19 08:44:14,953	INFO trainable.py:430 -- Current state after restoring: {'_iteration': 1330, '_timesteps_total': None, '_time_total': 631.2472841739655, '_episodes_total': None}
# (pid=26728) 2020-07-19 08:44:19,112	INFO trainable.py:423 -- Restored on 192.168.1.149 from checkpoint: /Users/deanwampler/ray_results/TrainMNIST/TrainMNIST_0_2020-07-19_08-33-07uc57ewdo/tmpdoe3nvmyrestore_from_object/checkpoint
# (pid=26728) 2020-07-19 08:44:19,113	INFO trainable.py:430 -- Current state after restoring: {'_iteration': 1360, '_timesteps_total': None, '_time_total': 645.7453458309174, '_episodes_total': None}
# (pid=26732) 2020-07-19 08:44:23,103	INFO trainable.py:423 -- Restored on 192.168.1.149 from checkpoint: /Users/deanwampler/ray_results/TrainMNIST/TrainMNIST_2_2020-07-19_08-33-07vmh5os0q/tmp7akm5aqbrestore_from_object/checkpoint
# (pid=26732) 2020-07-19 08:44:23,103	INFO trainable.py:430 -- Current state after restoring: {'_iteration': 1350, '_timesteps_total': None, '_time_total': 641.6399400234222, '_episodes_total': None}
# (pid=26736) 2020-07-19 08:44:27,817	INFO trainable.py:423 -- Restored on 192.168.1.149 from checkpoint: /Users/deanwampler/ray_results/TrainMNIST/TrainMNIST_0_2020-07-19_08-33-07uc57ewdo/tmpfdwbyvq7restore_from_object/checkpoint
# (pid=26736) 2020-07-19 08:44:27,817	INFO trainable.py:430 -- Current state after restoring: {'_iteration': 1380, '_timesteps_total': None, '_time_total': 654.5659403800964, '_episodes_total': None}
# (pid=26740) 2020-07-19 08:44:32,834	INFO trainable.py:423 -- Restored on 192.168.1.149 from checkpoint: /Users/deanwampler/ray_results/TrainMNIST/TrainMNIST_2_2020-07-19_08-33-07vmh5os0q/tmppbrw7d9jrestore_from_object/checkpoint
# (pid=26740) 2020-07-19 08:44:32,834	INFO trainable.py:430 -- Current state after restoring: {'_iteration': 1390, '_timesteps_total': None, '_time_total': 658.945797920227, '_episodes_total': None}
# (pid=26743) 2020-07-19 08:44:37,673	INFO trainable.py:423 -- Restored on 192.168.1.149 from checkpoint: /Users/deanwampler/ray_results/TrainMNIST/TrainMNIST_0_2020-07-19_08-33-07uc57ewdo/tmp273dm2rkrestore_from_object/checkpoint
# (pid=26743) 2020-07-19 08:44:37,673	INFO trainable.py:430 -- Current state after restoring: {'_iteration': 1370, '_timesteps_total': None, '_time_total': 649.8991346359253, '_episodes_total': None}
# (pid=26750) 2020-07-19 08:44:42,270	INFO trainable.py:423 -- Restored on 192.168.1.149 from checkpoint: /Users/deanwampler/ray_results/TrainMNIST/TrainMNIST_2_2020-07-19_08-33-07vmh5os0q/tmpxfr00aw9restore_from_object/checkpoint
# (pid=26750) 2020-07-19 08:44:42,271	INFO trainable.py:430 -- Current state after restoring: {'_iteration': 1380, '_timesteps_total': None, '_time_total': 661.4893620014191, '_episodes_total': None}
# (pid=26754) 2020-07-19 08:44:46,548	INFO trainable.py:423 -- Restored on 192.168.1.149 from checkpoint: /Users/deanwampler/ray_results/TrainMNIST/TrainMNIST_0_2020-07-19_08-33-07uc57ewdo/tmpl_7uy8fsrestore_from_object/checkpoint
# (pid=26754) 2020-07-19 08:44:46,548	INFO trainable.py:430 -- Current state after restoring: {'_iteration': 1420, '_timesteps_total': None, '_time_total': 674.3850994110107, '_episodes_total': None}
# (pid=26757) 2020-07-19 08:44:50,726	INFO trainable.py:423 -- Restored on 192.168.1.149 from checkpoint: /Users/deanwampler/ray_results/TrainMNIST/TrainMNIST_2_2020-07-19_08-33-07vmh5os0q/tmpggj8ijgirestore_from_object/checkpoint
# (pid=26757) 2020-07-19 08:44:50,726	INFO trainable.py:430 -- Current state after restoring: {'_iteration': 1400, '_timesteps_total': None, '_time_total': 671.2259335517883, '_episodes_total': None}
# (pid=26764) 2020-07-19 08:45:03,851	INFO trainable.py:423 -- Restored on 192.168.1.149 from checkpoint: /Users/deanwampler/ray_results/TrainMNIST/TrainMNIST_0_2020-07-19_08-33-07uc57ewdo/tmpcx6bn3zzrestore_from_object/checkpoint
# (pid=26764) 2020-07-19 08:45:03,851	INFO trainable.py:430 -- Current state after restoring: {'_iteration': 1430, '_timesteps_total': None, '_time_total': 678.2855904102325, '_episodes_total': None}
# (pid=26766) 2020-07-19 08:45:03,967	INFO trainable.py:423 -- Restored on 192.168.1.149 from checkpoint: /Users/deanwampler/ray_results/TrainMNIST/TrainMNIST_2_2020-07-19_08-33-07vmh5os0q/tmp0zaxftmcrestore_from_object/checkpoint
# (pid=26766) 2020-07-19 08:45:03,967	INFO trainable.py:430 -- Current state after restoring: {'_iteration': 1430, '_timesteps_total': None, '_time_total': 684.2731528282166, '_episodes_total': None}
# (pid=26767) 2020-07-19 08:45:11,075	INFO trainable.py:423 -- Restored on 192.168.1.149 from checkpoint: /Users/deanwampler/ray_results/TrainMNIST/TrainMNIST_0_2020-07-19_08-33-07uc57ewdo/tmp20r0bgvmrestore_from_object/checkpoint
# (pid=26767) 2020-07-19 08:45:11,075	INFO trainable.py:430 -- Current state after restoring: {'_iteration': 1450, '_timesteps_total': None, '_time_total': 693.7922930717468, '_episodes_total': None}
# (pid=26768) 2020-07-19 08:45:11,117	INFO trainable.py:423 -- Restored on 192.168.1.149 from checkpoint: /Users/deanwampler/ray_results/TrainMNIST/TrainMNIST_2_2020-07-19_08-33-07vmh5os0q/tmpfmd15jdwrestore_from_object/checkpoint
# (pid=26768) 2020-07-19 08:45:11,118	INFO trainable.py:430 -- Current state after restoring: {'_iteration': 1450, '_timesteps_total': None, '_time_total': 693.7922930717468, '_episodes_total': None}
# (pid=26765) 2020-07-19 08:45:24,423	INFO trainable.py:423 -- Restored on 192.168.1.149 from checkpoint: /Users/deanwampler/ray_results/TrainMNIST/TrainMNIST_0_2020-07-19_08-33-07uc57ewdo/tmpz2aug2_xrestore_from_object/checkpoint
# (pid=26765) 2020-07-19 08:45:24,424	INFO trainable.py:430 -- Current state after restoring: {'_iteration': 1500, '_timesteps_total': None, '_time_total': 711.3815801143646, '_episodes_total': None}
# (pid=26784) 2020-07-19 08:45:30,936	INFO trainable.py:423 -- Restored on 192.168.1.149 from checkpoint: /Users/deanwampler/ray_results/TrainMNIST/TrainMNIST_2_2020-07-19_08-33-07vmh5os0q/tmpdfm0uug1restore_from_object/checkpoint
# (pid=26784) 2020-07-19 08:45:30,936	INFO trainable.py:430 -- Current state after restoring: {'_iteration': 1480, '_timesteps_total': None, '_time_total': 708.9384167194366, '_episodes_total': None}
# (pid=26156) 2020-07-19 08:45:32,658	ERROR worker.py:374 -- SystemExit was raised from the worker
# (pid=26156) Traceback (most recent call last):
# (pid=26156)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages/ray/function_manager.py", line 559, in actor_method_executor
# (pid=26156)     method_returns = method(actor, *args, **kwargs)
# (pid=26156)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages/ray/tune/trainable.py", line 261, in train
# (pid=26156)     result = self._train()
# (pid=26156)   File "/Users/deanwampler/projects/anyscale/academy/academy-git/ray-tune/mnist.py", line 132, in _train
# (pid=26156)     self.train_step(self.model, self.optimizer, self.train_loader)
# (pid=26156)   File "/Users/deanwampler/projects/anyscale/academy/academy-git/ray-tune/mnist.py", line 60, in train_step
# (pid=26156)     for batch_idx, (data, target) in enumerate(train_loader):
# (pid=26156)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages/torch/utils/data/dataloader.py", line 345, in __next__
# (pid=26156)     data = self._next_data()
# (pid=26156)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages/torch/utils/data/dataloader.py", line 385, in _next_data
# (pid=26156)     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
# (pid=26156)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages/torch/utils/data/_utils/fetch.py", line 44, in fetch
# (pid=26156)     data = [self.dataset[idx] for idx in possibly_batched_index]
# (pid=26156)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages/torch/utils/data/_utils/fetch.py", line 44, in <listcomp>
# (pid=26156)     data = [self.dataset[idx] for idx in possibly_batched_index]
# (pid=26156)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages/torchvision/datasets/mnist.py", line 97, in __getitem__
# (pid=26156)     img = self.transform(img)
# (pid=26156)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages/torchvision/transforms/transforms.py", line 61, in __call__
# (pid=26156)     img = t(img)
# (pid=26156)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages/torchvision/transforms/transforms.py", line 92, in __call__
# (pid=26156)     return F.to_tensor(pic)
# (pid=26156)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages/torchvision/transforms/functional.py", line 76, in to_tensor
# (pid=26156)     img = img.view(pic.size[1], pic.size[0], len(pic.getbands()))
# (pid=26156)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages/ray/worker.py", line 371, in sigterm_handler
# (pid=26156)     sys.exit(1)
# (pid=26156) SystemExit: 1
# (pid=26156)
# (pid=26156) During handling of the above exception, another exception occurred:
# (pid=26156)
# (pid=26156) Traceback (most recent call last):
# (pid=26156)   File "python/ray/_raylet.pyx", line 514, in ray._raylet.task_execution_handler
# (pid=26156)   File "python/ray/_raylet.pyx", line 402, in ray._raylet.execute_task
# (pid=26156)   File "python/ray/_raylet.pyx", line 442, in ray._raylet.execute_task
# (pid=26156)   File "python/ray/_raylet.pyx", line 445, in ray._raylet.execute_task
# (pid=26156)   File "python/ray/_raylet.pyx", line 446, in ray._raylet.execute_task
# (pid=26156)   File "python/ray/_raylet.pyx", line 400, in ray._raylet.execute_task.function_executor
# (pid=26156)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages/ray/function_manager.py", line 559, in actor_method_executor
# (pid=26156)     method_returns = method(actor, *args, **kwargs)
# (pid=26156)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages/ray/worker.py", line 371, in sigterm_handler
# (pid=26156)     sys.exit(1)
# (pid=26156) SystemExit: 1
# (pid=26160) 2020-07-19 08:45:32,658	ERROR worker.py:374 -- SystemExit was raised from the worker
# (pid=26160) Traceback (most recent call last):
# (pid=26160)   File "python/ray/_raylet.pyx", line 445, in ray._raylet.execute_task
# (pid=26160)   File "python/ray/_raylet.pyx", line 446, in ray._raylet.execute_task
# (pid=26160)   File "python/ray/_raylet.pyx", line 400, in ray._raylet.execute_task.function_executor
# (pid=26160)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages/ray/function_manager.py", line 559, in actor_method_executor
# (pid=26160)     method_returns = method(actor, *args, **kwargs)
# (pid=26160)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages/ray/tune/trainable.py", line 261, in train
# (pid=26160)     result = self._train()
# (pid=26160)   File "/Users/deanwampler/projects/anyscale/academy/academy-git/ray-tune/mnist.py", line 132, in _train
# (pid=26160)     self.train_step(self.model, self.optimizer, self.train_loader)
# (pid=26160)   File "/Users/deanwampler/projects/anyscale/academy/academy-git/ray-tune/mnist.py", line 60, in train_step
# (pid=26160)     for batch_idx, (data, target) in enumerate(train_loader):
# (pid=26160)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages/torch/utils/data/dataloader.py", line 345, in __next__
# (pid=26160)     data = self._next_data()
# (pid=26160)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages/torch/utils/data/dataloader.py", line 385, in _next_data
# (pid=26160)     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
# (pid=26160)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages/torch/utils/data/_utils/fetch.py", line 44, in fetch
# (pid=26160)     data = [self.dataset[idx] for idx in possibly_batched_index]
# (pid=26160)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages/torch/utils/data/_utils/fetch.py", line 44, in <listcomp>
# (pid=26160)     data = [self.dataset[idx] for idx in possibly_batched_index]
# (pid=26160)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages/torchvision/datasets/mnist.py", line 97, in __getitem__
# (pid=26160)     img = self.transform(img)
# (pid=26160)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages/torchvision/transforms/transforms.py", line 61, in __call__
# (pid=26160)     img = t(img)
# (pid=26160)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages/torchvision/transforms/transforms.py", line 166, in __call__
# (pid=26160)     return F.normalize(tensor, self.mean, self.std, self.inplace)
# (pid=26160)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages/torchvision/transforms/functional.py", line 201, in normalize
# (pid=26160)     std = torch.as_tensor(std, dtype=dtype, device=tensor.device)
# (pid=26160)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages/ray/worker.py", line 371, in sigterm_handler
# (pid=26160)     sys.exit(1)
# (pid=26160) SystemExit: 1
# (pid=26160)
# (pid=26160) During handling of the above exception, another exception occurred:
# (pid=26160)
# (pid=26160) Traceback (most recent call last):
# (pid=26160)   File "python/ray/_raylet.pyx", line 514, in ray._raylet.task_execution_handler
# (pid=26160)   File "python/ray/_raylet.pyx", line 402, in ray._raylet.execute_task
# (pid=26160)   File "python/ray/_raylet.pyx", line 442, in ray._raylet.execute_task
# (pid=26160)   File "python/ray/includes/libcoreworker.pxi", line 33, in ray._raylet.ProfileEvent.__exit__
# (pid=26160)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/traceback.py", line 167, in format_exc
# (pid=26160)     return "".join(format_exception(*sys.exc_info(), limit=limit, chain=chain))
# (pid=26160)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/traceback.py", line 121, in format_exception
# (pid=26160)     type(value), value, tb, limit=limit).format(chain=chain))
# (pid=26160)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/traceback.py", line 508, in __init__
# (pid=26160)     capture_locals=capture_locals)
# (pid=26160)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/traceback.py", line 363, in extract
# (pid=26160)     f.line
# (pid=26160)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/traceback.py", line 285, in line
# (pid=26160)     self._line = linecache.getline(self.filename, self.lineno).strip()
# (pid=26160)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/linecache.py", line 16, in getline
# (pid=26160)     lines = getlines(filename, module_globals)
# (pid=26160)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/linecache.py", line 47, in getlines
# (pid=26160)     return updatecache(filename, module_globals)
# (pid=26160)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/linecache.py", line 136, in updatecache
# (pid=26160)     with tokenize.open(fullname) as fp:
# (pid=26160)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/tokenize.py", line 449, in open
# (pid=26160)     encoding, lines = detect_encoding(buffer.readline)
# (pid=26160)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/tokenize.py", line 418, in detect_encoding
# (pid=26160)     first = read_or_stop()
# (pid=26160)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/tokenize.py", line 376, in read_or_stop
# (pid=26160)     return readline()
# (pid=26160)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages/ray/worker.py", line 371, in sigterm_handler
# (pid=26160)     sys.exit(1)
# (pid=26160) SystemExit: 1
# (pid=26187) 2020-07-19 08:45:32,665	ERROR worker.py:374 -- SystemExit was raised from the worker
# (pid=26187) Traceback (most recent call last):
# (pid=26187)   File "python/ray/_raylet.pyx", line 514, in ray._raylet.task_execution_handler
# (pid=26187)   File "python/ray/_raylet.pyx", line 402, in ray._raylet.execute_task
# (pid=26187)   File "python/ray/_raylet.pyx", line 442, in ray._raylet.execute_task
# (pid=26187)   File "python/ray/_raylet.pyx", line 445, in ray._raylet.execute_task
# (pid=26187)   File "python/ray/_raylet.pyx", line 446, in ray._raylet.execute_task
# (pid=26187)   File "python/ray/_raylet.pyx", line 400, in ray._raylet.execute_task.function_executor
# (pid=26187)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages/ray/function_manager.py", line 559, in actor_method_executor
# (pid=26187)     method_returns = method(actor, *args, **kwargs)
# (pid=26187)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages/ray/tune/trainable.py", line 261, in train
# (pid=26187)     result = self._train()
# (pid=26187)   File "/Users/deanwampler/projects/anyscale/academy/academy-git/ray-tune/mnist.py", line 132, in _train
# (pid=26187)     self.train_step(self.model, self.optimizer, self.train_loader)
# (pid=26187)   File "/Users/deanwampler/projects/anyscale/academy/academy-git/ray-tune/mnist.py", line 66, in train_step
# (pid=26187)     loss = F.nll_loss(output, target)
# (pid=26187)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages/ray/worker.py", line 371, in sigterm_handler
# (pid=26187)     sys.exit(1)
# (pid=26187) SystemExit: 1
# (pid=26191) 2020-07-19 08:45:32,665	ERROR worker.py:374 -- SystemExit was raised from the worker
# (pid=26191) Traceback (most recent call last):
# (pid=26191)   File "python/ray/_raylet.pyx", line 514, in ray._raylet.task_execution_handler
# (pid=26191)   File "python/ray/_raylet.pyx", line 402, in ray._raylet.execute_task
# (pid=26191)   File "python/ray/_raylet.pyx", line 442, in ray._raylet.execute_task
# (pid=26191)   File "python/ray/_raylet.pyx", line 445, in ray._raylet.execute_task
# (pid=26191)   File "python/ray/_raylet.pyx", line 446, in ray._raylet.execute_task
# (pid=26191)   File "python/ray/_raylet.pyx", line 400, in ray._raylet.execute_task.function_executor
# (pid=26191)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages/ray/function_manager.py", line 559, in actor_method_executor
# (pid=26191)     method_returns = method(actor, *args, **kwargs)
# (pid=26191)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages/ray/tune/trainable.py", line 261, in train
# (pid=26191)     result = self._train()
# (pid=26191)   File "/Users/deanwampler/projects/anyscale/academy/academy-git/ray-tune/mnist.py", line 133, in _train
# (pid=26191)     acc = self.test_step(self.model, self.test_loader)
# (pid=26191)   File "/Users/deanwampler/projects/anyscale/academy/academy-git/ray-tune/mnist.py", line 79, in test_step
# (pid=26191)     for batch_idx, (data, target) in enumerate(data_loader):
# (pid=26191)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages/torch/utils/data/dataloader.py", line 345, in __next__
# (pid=26191)     data = self._next_data()
# (pid=26191)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages/torch/utils/data/dataloader.py", line 385, in _next_data
# (pid=26191)     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
# (pid=26191)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages/torch/utils/data/_utils/fetch.py", line 44, in fetch
# (pid=26191)     data = [self.dataset[idx] for idx in possibly_batched_index]
# (pid=26191)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages/torch/utils/data/_utils/fetch.py", line 44, in <listcomp>
# (pid=26191)     data = [self.dataset[idx] for idx in possibly_batched_index]
# (pid=26191)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages/torchvision/datasets/mnist.py", line 97, in __getitem__
# (pid=26191)     img = self.transform(img)
# (pid=26191)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages/torchvision/transforms/transforms.py", line 61, in __call__
# (pid=26191)     img = t(img)
# (pid=26191)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages/torchvision/transforms/transforms.py", line 92, in __call__
# (pid=26191)     return F.to_tensor(pic)
# (pid=26191)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages/torchvision/transforms/functional.py", line 78, in to_tensor
# (pid=26191)     img = img.permute((2, 0, 1)).contiguous()
# (pid=26191)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages/ray/worker.py", line 371, in sigterm_handler
# (pid=26191)     sys.exit(1)
# (pid=26191) SystemExit: 1
# (pid=26245) 2020-07-19 08:45:32,659	ERROR worker.py:374 -- SystemExit was raised from the worker
# (pid=26245) Traceback (most recent call last):
# (pid=26245)   File "python/ray/_raylet.pyx", line 445, in ray._raylet.execute_task
# (pid=26245)   File "python/ray/_raylet.pyx", line 446, in ray._raylet.execute_task
# (pid=26245)   File "python/ray/_raylet.pyx", line 400, in ray._raylet.execute_task.function_executor
# (pid=26245)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages/ray/function_manager.py", line 559, in actor_method_executor
# (pid=26245)     method_returns = method(actor, *args, **kwargs)
# (pid=26245)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages/ray/tune/trainable.py", line 261, in train
# (pid=26245)     result = self._train()
# (pid=26245)   File "/Users/deanwampler/projects/anyscale/academy/academy-git/ray-tune/mnist.py", line 132, in _train
# (pid=26245)     self.train_step(self.model, self.optimizer, self.train_loader)
# (pid=26245)   File "/Users/deanwampler/projects/anyscale/academy/academy-git/ray-tune/mnist.py", line 60, in train_step
# (pid=26245)     for batch_idx, (data, target) in enumerate(train_loader):
# (pid=26245)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages/torch/utils/data/dataloader.py", line 345, in __next__
# (pid=26245)     data = self._next_data()
# (pid=26245)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages/torch/utils/data/dataloader.py", line 385, in _next_data
# (pid=26245)     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
# (pid=26245)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages/torch/utils/data/_utils/fetch.py", line 44, in fetch
# (pid=26245)     data = [self.dataset[idx] for idx in possibly_batched_index]
# (pid=26245)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages/torch/utils/data/_utils/fetch.py", line 44, in <listcomp>
# (pid=26245)     data = [self.dataset[idx] for idx in possibly_batched_index]
# (pid=26245)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages/torchvision/datasets/mnist.py", line 94, in __getitem__
# (pid=26245)     img = Image.fromarray(img.numpy(), mode='L')
# (pid=26245)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages/PIL/Image.py", line 2735, in fromarray
# (pid=26245)     return frombuffer(mode, size, obj, "raw", rawmode, 0, 1)
# (pid=26245)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages/PIL/Image.py", line 2670, in frombuffer
# (pid=26245)     im = new(mode, (1, 1))
# (pid=26245)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages/PIL/Image.py", line 2578, in new
# (pid=26245)     return im._new(core.fill(mode, size, color))
# (pid=26245)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages/ray/worker.py", line 371, in sigterm_handler
# (pid=26245)     sys.exit(1)
# (pid=26245) SystemExit: 1
# (pid=26245)
# (pid=26245) During handling of the above exception, another exception occurred:
# (pid=26245)
# (pid=26245) Traceback (most recent call last):
# (pid=26245)   File "python/ray/_raylet.pyx", line 514, in ray._raylet.task_execution_handler
# (pid=26245)   File "python/ray/_raylet.pyx", line 402, in ray._raylet.execute_task
# (pid=26245)   File "python/ray/_raylet.pyx", line 442, in ray._raylet.execute_task
# (pid=26245)   File "python/ray/includes/libcoreworker.pxi", line 33, in ray._raylet.ProfileEvent.__exit__
# (pid=26245)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/traceback.py", line 167, in format_exc
# (pid=26245)     return "".join(format_exception(*sys.exc_info(), limit=limit, chain=chain))
# (pid=26245)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/traceback.py", line 121, in format_exception
# (pid=26245)     type(value), value, tb, limit=limit).format(chain=chain))
# (pid=26245)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/traceback.py", line 508, in __init__
# (pid=26245)     capture_locals=capture_locals)
# (pid=26245)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/traceback.py", line 363, in extract
# (pid=26245)     f.line
# (pid=26245)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/traceback.py", line 285, in line
# (pid=26245)     self._line = linecache.getline(self.filename, self.lineno).strip()
# (pid=26245)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/linecache.py", line 16, in getline
# (pid=26245)     lines = getlines(filename, module_globals)
# (pid=26245)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/linecache.py", line 47, in getlines
# (pid=26245)     return updatecache(filename, module_globals)
# (pid=26245)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/linecache.py", line 136, in updatecache
# (pid=26245)     with tokenize.open(fullname) as fp:
# (pid=26245)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/tokenize.py", line 449, in open
# (pid=26245)     encoding, lines = detect_encoding(buffer.readline)
# (pid=26245)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/tokenize.py", line 418, in detect_encoding
# (pid=26245)     first = read_or_stop()
# (pid=26245)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/tokenize.py", line 376, in read_or_stop
# (pid=26245)     return readline()
# (pid=26245)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages/ray/worker.py", line 371, in sigterm_handler
# (pid=26245)     sys.exit(1)
# (pid=26245) SystemExit: 1
# (pid=26518) 2020-07-19 08:45:32,658	ERROR worker.py:374 -- SystemExit was raised from the worker
# (pid=26518) Traceback (most recent call last):
# (pid=26518)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages/ray/function_manager.py", line 559, in actor_method_executor
# (pid=26518)     method_returns = method(actor, *args, **kwargs)
# (pid=26518)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages/ray/tune/trainable.py", line 261, in train
# (pid=26518)     result = self._train()
# (pid=26518)   File "/Users/deanwampler/projects/anyscale/academy/academy-git/ray-tune/mnist.py", line 132, in _train
# (pid=26518)     self.train_step(self.model, self.optimizer, self.train_loader)
# (pid=26518)   File "/Users/deanwampler/projects/anyscale/academy/academy-git/ray-tune/mnist.py", line 60, in train_step
# (pid=26518)     for batch_idx, (data, target) in enumerate(train_loader):
# (pid=26518)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages/torch/utils/data/dataloader.py", line 345, in __next__
# (pid=26518)     data = self._next_data()
# (pid=26518)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages/torch/utils/data/dataloader.py", line 385, in _next_data
# (pid=26518)     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
# (pid=26518)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages/torch/utils/data/_utils/fetch.py", line 44, in fetch
# (pid=26518)     data = [self.dataset[idx] for idx in possibly_batched_index]
# (pid=26518)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages/torch/utils/data/_utils/fetch.py", line 44, in <listcomp>
# (pid=26518)     data = [self.dataset[idx] for idx in possibly_batched_index]
# (pid=26518)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages/torchvision/datasets/mnist.py", line 97, in __getitem__
# (pid=26518)     img = self.transform(img)
# (pid=26518)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages/torchvision/transforms/transforms.py", line 61, in __call__
# (pid=26518)     img = t(img)
# (pid=26518)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages/torchvision/transforms/transforms.py", line 92, in __call__
# (pid=26518)     return F.to_tensor(pic)
# (pid=26518)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages/torchvision/transforms/functional.py", line 80, in to_tensor
# (pid=26518)     return img.float().div(255)
# (pid=26518)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages/ray/worker.py", line 371, in sigterm_handler
# (pid=26518)     sys.exit(1)
# (pid=26518) SystemExit: 1
# (pid=26518)
# (pid=26518) During handling of the above exception, another exception occurred:
# (pid=26518)
# (pid=26518) Traceback (most recent call last):
# (pid=26518)   File "python/ray/_raylet.pyx", line 514, in ray._raylet.task_execution_handler
# (pid=26518)   File "python/ray/_raylet.pyx", line 402, in ray._raylet.execute_task
# (pid=26518)   File "python/ray/_raylet.pyx", line 442, in ray._raylet.execute_task
# (pid=26518)   File "python/ray/_raylet.pyx", line 445, in ray._raylet.execute_task
# (pid=26518)   File "python/ray/_raylet.pyx", line 446, in ray._raylet.execute_task
# (pid=26518)   File "python/ray/_raylet.pyx", line 400, in ray._raylet.execute_task.function_executor
# (pid=26518)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages/ray/function_manager.py", line 559, in actor_method_executor
# (pid=26518)     method_returns = method(actor, *args, **kwargs)
# (pid=26518)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages/ray/worker.py", line 371, in sigterm_handler
# (pid=26518)     sys.exit(1)
# (pid=26518) SystemExit: 1
# (pid=26784) 2020-07-19 08:45:32,656	ERROR worker.py:374 -- SystemExit was raised from the worker
# (pid=26784) Traceback (most recent call last):
# (pid=26784)   File "/Users/deanwampler/projects/anyscale/academy/academy-git/ray-tune/mnist.py", line 79, in test_step
# (pid=26784)     for batch_idx, (data, target) in enumerate(data_loader):
# (pid=26784)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages/torch/utils/data/dataloader.py", line 345, in __next__
# (pid=26784)     data = self._next_data()
# (pid=26784)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages/torch/utils/data/dataloader.py", line 385, in _next_data
# (pid=26784)     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
# (pid=26784)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages/torch/utils/data/_utils/fetch.py", line 44, in fetch
# (pid=26784)     data = [self.dataset[idx] for idx in possibly_batched_index]
# (pid=26784)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages/torch/utils/data/_utils/fetch.py", line 44, in <listcomp>
# (pid=26784)     data = [self.dataset[idx] for idx in possibly_batched_index]
# (pid=26784)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages/torchvision/datasets/mnist.py", line 90, in __getitem__
# (pid=26784)     img, target = self.data[index], int(self.targets[index])
# (pid=26784)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages/ray/worker.py", line 371, in sigterm_handler
# (pid=26784)     sys.exit(1)
# (pid=26784) SystemExit: 1
# (pid=26784)
# (pid=26784) During handling of the above exception, another exception occurred:
# (pid=26784)
# (pid=26784) Traceback (most recent call last):
# (pid=26784)   File "python/ray/_raylet.pyx", line 514, in ray._raylet.task_execution_handler
# (pid=26784)   File "python/ray/_raylet.pyx", line 402, in ray._raylet.execute_task
# (pid=26784)   File "python/ray/_raylet.pyx", line 442, in ray._raylet.execute_task
# (pid=26784)   File "python/ray/_raylet.pyx", line 445, in ray._raylet.execute_task
# (pid=26784)   File "python/ray/_raylet.pyx", line 446, in ray._raylet.execute_task
# (pid=26784)   File "python/ray/_raylet.pyx", line 400, in ray._raylet.execute_task.function_executor
# (pid=26784)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages/ray/function_manager.py", line 559, in actor_method_executor
# (pid=26784)     method_returns = method(actor, *args, **kwargs)
# (pid=26784)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages/ray/tune/trainable.py", line 261, in train
# (pid=26784)     result = self._train()
# (pid=26784)   File "/Users/deanwampler/projects/anyscale/academy/academy-git/ray-tune/mnist.py", line 133, in _train
# (pid=26784)     acc = self.test_step(self.model, self.test_loader)
# (pid=26784)   File "/Users/deanwampler/projects/anyscale/academy/academy-git/ray-tune/mnist.py", line 79, in test_step
# (pid=26784)     for batch_idx, (data, target) in enumerate(data_loader):
# (pid=26784)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages/ray/worker.py", line 371, in sigterm_handler
# (pid=26784)     sys.exit(1)
# (pid=26784) SystemExit: 1
# (pid=26788) 2020-07-19 08:45:32,654	ERROR worker.py:374 -- SystemExit was raised from the worker
# (pid=26788) Traceback (most recent call last):
# (pid=26788)   File "<frozen importlib._bootstrap>", line 677, in _load_unlocked
# (pid=26788)   File "<frozen importlib._bootstrap_external>", line 724, in exec_module
# (pid=26788)   File "<frozen importlib._bootstrap_external>", line 857, in get_code
# (pid=26788)   File "<frozen importlib._bootstrap_external>", line 525, in _compile_bytecode
# (pid=26788)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages/ray/worker.py", line 371, in sigterm_handler
# (pid=26788)     sys.exit(1)
# (pid=26788) SystemExit: 1
# (pid=26788)
# (pid=26788) During handling of the above exception, another exception occurred:
# (pid=26788)
# (pid=26788) Traceback (most recent call last):
# (pid=26788)   File "python/ray/_raylet.pyx", line 514, in ray._raylet.task_execution_handler
# (pid=26788)   File "python/ray/_raylet.pyx", line 335, in ray._raylet.execute_task
# (pid=26788)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages/ray/function_manager.py", line 397, in load_actor_class
# (pid=26788)     job_id, actor_creation_function_descriptor)
# (pid=26788)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages/ray/function_manager.py", line 494, in _load_actor_class_from_gcs
# (pid=26788)     actor_class = pickle.loads(pickled_class)
# (pid=26788)   File "/Users/deanwampler/projects/anyscale/academy/academy-git/ray-tune/mnist.py", line 9, in <module>
# (pid=26788)     from ray import tune
# (pid=26788)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages/ray/tune/__init__.py", line 2, in <module>
# (pid=26788)     from ray.tune.tune import run_experiments, run
# (pid=26788)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages/ray/tune/tune.py", line 5, in <module>
# (pid=26788)     from ray.tune.analysis import ExperimentAnalysis
# (pid=26788)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages/ray/tune/analysis/__init__.py", line 1, in <module>
# (pid=26788)     from ray.tune.analysis.experiment_analysis import ExperimentAnalysis, Analysis
# (pid=26788)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages/ray/tune/analysis/experiment_analysis.py", line 6, in <module>
# (pid=26788)     import pandas as pd
# (pid=26788)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages/pandas/__init__.py", line 55, in <module>
# (pid=26788)     from pandas.core.api import (
# (pid=26788)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages/pandas/core/api.py", line 29, in <module>
# (pid=26788)     from pandas.core.groupby import Grouper, NamedAgg
# (pid=26788)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages/pandas/core/groupby/__init__.py", line 1, in <module>
# (pid=26788)     from pandas.core.groupby.generic import DataFrameGroupBy, NamedAgg, SeriesGroupBy
# (pid=26788)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages/pandas/core/groupby/generic.py", line 60, in <module>
# (pid=26788)     from pandas.core.frame import DataFrame
# (pid=26788)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages/pandas/core/frame.py", line 124, in <module>
# (pid=26788)     from pandas.core.series import Series
# (pid=26788)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages/pandas/core/series.py", line 82, in <module>
# (pid=26788)     import pandas.plotting
# (pid=26788)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages/pandas/plotting/__init__.py", line 58, in <module>
# (pid=26788)     from pandas.plotting._core import (
# (pid=26788)   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
# (pid=26788)   File "<frozen importlib._bootstrap>", line 967, in _find_and_load_unlocked
# (pid=26788)   File "<frozen importlib._bootstrap>", line 677, in _load_unlocked
# (pid=26788)   File "/Users/deanwampler/anaconda3/envs/anyscale-academy/lib/python3.7/site-packages/ray/worker.py", line 371, in sigterm_handler
# (pid=26788)     sys.exit(1)
# (pid=26788) SystemExit: 1
# (pid=26810) 2020-07-19 08:45:41,945	WARNING deprecation.py:30 -- DeprecationWarning: `eager` has been deprecated. Use `framework=tfe` instead. This will raise an error in the future!
# (pid=26810) 2020-07-19 08:45:41,945	INFO trainer.py:585 -- Tip: set framework=tfe or the --eager flag to enable TensorFlow eager execution
# (pid=26810) 2020-07-19 08:45:41,945	INFO trainer.py:612 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# (pid=26810) 2020-07-19 08:45:46,069	WARNING util.py:37 -- Install gputil for GPU system monitoring.
# (pid=26828) 2020-07-19 08:46:36,574	WARNING deprecation.py:30 -- DeprecationWarning: `eager` has been deprecated. Use `framework=tfe` instead. This will raise an error in the future!
# (pid=26828) 2020-07-19 08:46:36,574	INFO trainer.py:585 -- Tip: set framework=tfe or the --eager flag to enable TensorFlow eager execution
# (pid=26828) 2020-07-19 08:46:36,574	INFO trainer.py:612 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# (pid=26828) 2020-07-19 08:46:39,458	WARNING util.py:37 -- Install gputil for GPU system monitoring.
# (pid=26929) 2020-07-19 08:47:29,697	WARNING deprecation.py:30 -- DeprecationWarning: `eager` has been deprecated. Use `framework=tfe` instead. This will raise an error in the future!
# (pid=26929) 2020-07-19 08:47:29,697	INFO trainer.py:585 -- Tip: set framework=tfe or the --eager flag to enable TensorFlow eager execution
# (pid=26929) 2020-07-19 08:47:29,697	INFO trainer.py:612 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# (pid=26929) 2020-07-19 08:47:33,469	WARNING util.py:37 -- Install gputil for GPU system monitoring.
# (pid=26956) 2020-07-19 08:48:17,814	WARNING deprecation.py:30 -- DeprecationWarning: `eager` has been deprecated. Use `framework=tfe` instead. This will raise an error in the future!
# (pid=26956) 2020-07-19 08:48:17,814	INFO trainer.py:585 -- Tip: set framework=tfe or the --eager flag to enable TensorFlow eager execution
# (pid=26956) 2020-07-19 08:48:17,814	INFO trainer.py:612 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# (pid=26956) 2020-07-19 08:48:21,255	WARNING util.py:37 -- Install gputil for GPU system monitoring.
# (pid=27112) 2020-07-19 08:49:08,495	WARNING deprecation.py:30 -- DeprecationWarning: `eager` has been deprecated. Use `framework=tfe` instead. This will raise an error in the future!
# (pid=27112) 2020-07-19 08:49:08,495	INFO trainer.py:585 -- Tip: set framework=tfe or the --eager flag to enable TensorFlow eager execution
# (pid=27112) 2020-07-19 08:49:08,495	INFO trainer.py:612 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# (pid=27112) 2020-07-19 08:49:12,680	WARNING util.py:37 -- Install gputil for GPU system monitoring.
# (pid=27134) 2020-07-19 08:50:17,414	WARNING deprecation.py:30 -- DeprecationWarning: `eager` has been deprecated. Use `framework=tfe` instead. This will raise an error in the future!
# (pid=27134) 2020-07-19 08:50:17,414	INFO trainer.py:585 -- Tip: set framework=tfe or the --eager flag to enable TensorFlow eager execution
# (pid=27134) 2020-07-19 08:50:17,414	INFO trainer.py:612 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# (pid=27134) 2020-07-19 08:50:20,558	WARNING util.py:37 -- Install gputil for GPU system monitoring.

# %% [markdown]
# Now modify the the following cell, copied from above, to use this scheduler:
# 1. Use the new scheduler.
# 2. Remove the search_alg argument.
# 3. Add the `config` argument.
# 4. Remove the `num_samples` argument.
# 5. Consider using `0` or `1` for the `verbose` argument.
#
# Then run it.
#
# > **WARNING:** This will run for a LONG time.

# %%
analysis = tune.run(TrainMNIST, 
    scheduler=scheduler, 
    search_alg=search_algorithm, 
    num_samples=12,                           # Force it try all 12 combinations
    verbose=2,                                # Change to 0 or 1 to reduce the output.
    ray_auto_init=False                       # Don't allow Tune to initialize Ray.
)

# %% [markdown]
# Look at the `analysis` data of interest, as done previously. How well does PBT work?
