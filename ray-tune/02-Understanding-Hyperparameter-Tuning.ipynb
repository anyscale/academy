# %% [markdown]
# # Ray Tune - Understanding Hyperparameter Tuning
#
# © 2019-2021, Anyscale. All Rights Reserved
#
# ![Anyscale Academy](../images/AnyscaleAcademyLogo.png)

# %% [markdown]
# Many of the [Ray RLlib](../ray-rllib/00-Ray-RLlib-Overview.ipynb) lessons used [Ray Tune](http://tune.io) to train policies. This meant we trained _parameters_ that defined the policies. Now we'll learn that Ray Tune was actually designed to determine the best _hyperparameters_ for the problem, before training to determine the _parameters_.
#
# This lesson introduces the concepts of _Hyperparameter Tuning or Optimization_ (HPO) and works through a nontrivial example using Tune.
#
# See also the [Hyperparameter Tuning References](References-Hyperparameter-Tuning.ipynb) notebook and the [Tune documentation](http://tune.io), in particular, the [API reference](https://docs.ray.io/en/latest/tune/api_docs/overview.html).
#
# A [Ray Summit Connect](https://anyscale.com/blog/videos-and-slides-for-the-second-ray-summit-connect-june-17-2020/) talk by the creator of Tune, Richard Liaw, provides an excellent overview of the challenges of hyperparameter tuning and how Tune addresses these challenges. Another recent webinar [Fast and efficient hyperparameter tuning with Ray Tune](https://www.anyscale.com/events/2021/10/20/fast-scalable-hyperparameter-tuning-ray-tune) complements the discussion here.

# %% [markdown]
# ## What Are Hyperparameters?
#
# In _supervised learning_, we train a model with labeled data so the model can properly label new data values. Everything about the model is defined by a set of _parameters_, such as the weights in a linear regression.
#
# In contrast, the _hyperparameters_<sup>1</sup> define structural details about the kind of model itself, like whether or not we are using a linear regression or what architecture is best for a neural network, etc. Other quantities considered hyperparameters include learning rates, discount rates, etc. If we want our training process and resulting model to work well, we first need to determine the optimal or near-optimal set of hyperparameters.
#
# How do we determine the optimal hyperparameters? The most straightfoward approach is to perform a loop where we pick a candidate set of values from some reasonably inclusive list of possible values, train a model, compare the results achieved with previous loop iterations, and pick the set that performed best. This process is called _Hyperparameter Tuning_ or _Optimization_ (HPO).
#
# This simple algorithm can quickly become very expensive, however. Training a single neural networks can be compute intensive and the space of all possible architectures is huge. Hence, much of the research in hyperparameter tuning, especially for neural networks, focuses on ways to optimize HPO, such as early stopping and pruning the search space when some combinations appear to perform poorly.
#
# 1. _Hyperparameter_ is often spelled _hyper parameter_ or _hyper-parameter_, but we'll use the spelling with no space or dash.

# %% [markdown]
# ## A Simple Example: $k$-Means
#
# Let's start with a very simple example of HPO, finding $k$ in $k$-means.
#
# The $k$-means algorithm finds clusters in a data set. It's a canonical example of _unsupervised learning_, where information is extracted from a data set, rather than using labeled data to train a model for labelling new data, as in _supervised learning_. We won't discuss the algorithm details, but the essense of it involves a "guess" for the expected number of clusters, the $k$ value, then calculating $k$ centroids (the coordinates at the center), one per cluster, along with determining to which cluster each data point belongs. The details are in [$k$-means Wikipedia article](https://en.wikipedia.org/wiki/K-means_clustering). The following animation shows the algorithm in action for a two-dimensional data set where three clusters are evident.
#
# ![K-Means Convergence](../images/tune/K-means_convergence.gif)
#
# (source: [Wikipedia](https://en.wikipedia.org/wiki/K-means_clustering). [Larger Image](https://en.wikipedia.org/wiki/K-means_clustering#/media/File:K-means_convergence.gif))

# %% [markdown]
# While it is easy to see the clusters in this two-dimensional data set, that won't be for arbitrary datasets, especially those with more than three dimensions. Hence, we should determine the best $k$ value by trying many values and picking the value that appears to be best. In this case, "best" would mean that we minimize the distances between the datapoints and centroids.
#
# With just one hyperparameter, this problem is comparatively simple and brute force calculations to find the optimal $k$ is usually good enough.

# %% [markdown]
# ## HPO for Neural Networks
#
# Where HPO really becomes a challenge is finding the right neural network architecture for your problem. Why are neural networks a challenge? Consider this image of a typical architecture:
#
# ![Typical Neural Network](../images/tune/hpo-neural-network-example.png)
#
# Every number you see is a hyperparameter! So are the decisions about how many layers to have, what kind of layer to use for each layer, etc. The space of possible hyperparameters is enormous, too big to explore naively.
#
# So called _neural architecture search_ (NAS) has become a research field in its own right, along with general research in optimizing HPO.

# %% [markdown]
# ## Introduction to Ray Tune
#
# [Ray Tune](http://tune.io) is the Ray-based native library for hyperparameter tuning. Tune makes it nearly as easy to run distributed, parallelized HPO as it is to run trials on a single machine manually, one after the other.
#
# Tune is built as an extensible, pluggable framework, with built-in integrations for many frameworks, including [OpenAI Gym environments](https://gym.openai.com/envs/), [PyTorch](https://pytorch.org), [TensorFlow](http://tensorflow.org), and recently, [sci-kit learn](https://scikit-learn.org/stable/) (see [this recent blog post](https://medium.com/distributed-computing-with-ray/gridsearchcv-2-0-new-and-improved-ee56644cbabf)).
#
# Tune also integrates implementations of many state-of-the-art [search algorithms](https://docs.ray.io/en/latest/tune/api_docs/suggestion.html) and [schedulers](https://docs.ray.io/en/latest/tune/api_docs/schedulers.html), so it is easy to optimize your HPO process.

# %% [markdown]
# ## Using Ray Tune
#
# We used Ray Tune in several of the reinforcement learning lessons, where we actually didn't optimize any hyperparameters; we just used it to drive the RLlib training process. Now we'll see an example of HPO with Tune.

# %% [markdown]
# First, we want to make sure that Ray is running and we want to initialize Ray in this "driver" program explicitly.

# %%
import ray
from ray import tune

# %% [markdown]
# Now we start Ray in this "driver" program (notebook).

# %%
ray.init(ignore_reinit_error=True)
# Out:
# 2021-11-17 17:06:48,503	INFO services.py:1252 -- View the Ray dashboard at http://127.0.0.1:8266
# {'node_ip_address': '10.103.119.204',
#  'raylet_ip_address': '10.103.119.204',
#  'redis_address': '10.103.119.204:13609',
#  'object_store_address': '/tmp/ray/session_2021-11-17_17-06-46_870500_10080/sockets/plasma_store',
#  'raylet_socket_name': '/tmp/ray/session_2021-11-17_17-06-46_870500_10080/sockets/raylet',
#  'webui_url': '127.0.0.1:8266',
#  'session_dir': '/tmp/ray/session_2021-11-17_17-06-46_870500_10080',
#  'metrics_export_port': 63887,
#  'node_id': '3eda841fb77adab199c0502a7ad4a3e6bdb7db2c384d972ea9bd6c6f'}

# %% [markdown]
# In our [RLlib Simple Multi-Armed Bandit](../ray-rllib/multi-armed-bandits/03-Simple-Multi-Armed-Bandit.ipynb) lesson, we used Tune to train RLlib, but not train hyperparameters.
#
# Now we'll use Tune to train hyperparameters. We'll use the same experimental environment we used in our [RLlib `CartPole` lesson](../ray-rllib/explore-rllib/01-Application-Cart-Pole.ipynb).
#
# > **Aside:** In case you haven't gone through the [Ray RLlib tutorial](../ray-rllib/00-Ray-RLlib-Overview.ipynb), [CartPole](https://gym.openai.com/envs/CartPole-v1/) is an [OpenAI Gym](https://gym.openai.com/envs/) environment that simulates a cart that moves left or right while attempting to balance a vertical pole. A _policy_ is trained to optimize changing the velocity up and down to control right and left movement with the goal of keeping the pole balanced for as long as possible.
#
# The most important hyperparameters for `CartPole` are for the neural network used to learn how to balance the pole. A simple network suffices. We'll use a fully-connected network with two hidden layers, but use Tune to find an optimal choice for the sizes of the layers. To keep the computation tractable for our purposes, we'll just pick sizes from the list of 20 and 40.
#
# It's probably that some specific number between these 10 and 100 is optimal for one layer and a different number is optimal for the other layer. However, the computation required for trying all possible combinations is $O(n^2)$. You should consider trying more numbers if you don't mind waiting!
#
# However, the two we've chosen are good enough as we'll see. We'll consider what "good enough" means when we look at the results.
#
# The next cell runs Tune for this purpose. The comments explain what each argument does. We'll do four tries, one for each combination of the two possible values for the two hidden layers.
#
# > **Note:** `tune.run` will handle Ray initialization for us, if it isn't already initialized. To force Tune to throw an error instead, pass the argument `ray_auto_init=False`.
#
# The next cell will take 5-6 minutes to run.

# %%
analysis = tune.run(
    "PPO",                                    # Use proximal policy optimization to train 
    stop={"episode_reward_mean": 400},        # Stopping criteria, when average reward over the episodes
                                              # of training equals 400 out of a maximum possible 500 score.
    config={
        "env": "CartPole-v1",                 # Tune can associate this string with the environment.
        "num_gpus": 0,                        # If you have GPUs, go for it!
        "num_workers": 3,                     # Number of Ray workers to use; Use one LESS than 
                                              # the number of cores you want to use (or omit this argument)!
        "model": {                            # The NN model we'll optimize.
            'fcnet_hiddens': [                # "Fully-connected network with N hidden layers".
                tune.grid_search([20, 40]),   # Try these four values for layer one.
                tune.grid_search([20, 40])    # Try these four values for layer two.
            ]
        },
    },
    verbose=1
)
# Out:
# == Status ==<br>Memory usage on this node: 16.8/32.0 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/12 CPUs, 0/0 GPUs, 0.0/9.59 GiB heap, 0.0/4.8 GiB objects<br>Result logdir: /Users/jules/ray_results/PPO<br>Number of trials: 4/4 (4 TERMINATED)<br><br>
# (pid=10266) [2021-11-17 17:09:50,247 E 10266 1754742] raylet_client.cc:159: IOError: Broken pipe [RayletClient] Failed to disconnect from raylet.
# 2021-11-17 17:09:50,352	INFO tune.py:617 -- Total run time: 179.33 seconds (173.41 seconds for the tuning loop).

# %% [markdown]
# ## Understanding the Results
#
# First, how long did it take?

# %%
stats = analysis.stats()
secs = stats["timestamp"] - stats["start_time"]
print(f'{secs:7.2f} seconds, {secs/60.0:7.2f} minutes')
# Out:
#  165.46 seconds,    2.76 minutes

# %% [markdown]
# Which one performed best based on our stopping criteria, with mode modes of "max" or "min?

# %%
analysis.get_best_config(metric="episode_reward_mean", mode="min")
# Out:
# {'env': 'CartPole-v1',
#  'num_gpus': 0,
#  'num_workers': 3,
#  'model': {'fcnet_hiddens': [40, 20]}}

# %%
analysis.get_best_config(metric="episode_reward_mean", mode="max")
# Out:
# {'env': 'CartPole-v1',
#  'num_gpus': 0,
#  'num_workers': 3,
#  'model': {'fcnet_hiddens': [40, 40]}}

# %% [markdown]
# So, the smallest combination is good enough, even the best according to this metric!
#
# Let's look at the data for all of them:

# %%
df = analysis.dataframe()
df
# Out:
#    episode_reward_max  episode_reward_min  episode_reward_mean  \
# 0               500.0                85.0               416.97
# 1               500.0                32.0               409.58
# 2               500.0               104.0               417.61
# 3               500.0               150.0               419.04
#
#    episode_len_mean  episodes_this_iter  num_healthy_workers  timesteps_total  \
# 0            416.97                  17                    3            87978
# 1            409.58                  16                    3            87978
# 2            417.61                  16                    3            87978
# 3            419.04                  16                    3           103974
#
#    agent_timesteps_total  done  episodes_total  ...  \
# 0                  87978  True            1009  ...
# 1                  87978  True             950  ...
# 2                  87978  True             909  ...
# 3                 103974  True             929  ...
#
#    info/learner/default_policy/learner_stats/vf_loss  \
# 0                                          3593.4290
# 1                                          3660.8145
# 2                                          1982.9950
# 3                                          1562.2784
#
#   info/learner/default_policy/learner_stats/vf_explained_var  \
# 0                                           0.000011
# 1                                           0.000003
# 2                                           0.000051
# 3                                           0.000013
#
#   info/learner/default_policy/learner_stats/kl  \
# 0                                     0.002300
# 1                                     0.004048
# 2                                     0.003492
# 3                                     0.003186
#
#    info/learner/default_policy/learner_stats/entropy  \
# 0                                           0.536551
# 1                                           0.522606
# 2                                           0.524612
# 3                                           0.553878
#
#    info/learner/default_policy/learner_stats/entropy_coeff   config/env  \
# 0                                                0.0        CartPole-v1
# 1                                                0.0        CartPole-v1
# 2                                                0.0        CartPole-v1
# 3                                                0.0        CartPole-v1
#
#                   config/model config/num_gpus config/num_workers  \
# 0  {'fcnet_hiddens': [20, 20]}               0                  3
# 1  {'fcnet_hiddens': [40, 20]}               0                  3
# 2  {'fcnet_hiddens': [20, 40]}               0                  3
# 3  {'fcnet_hiddens': [40, 40]}               0                  3
#
#                                               logdir
# 0  /Users/jules/ray_results/PPO/PPO_CartPole-v1_d...
# 1  /Users/jules/ray_results/PPO/PPO_CartPole-v1_d...
# 2  /Users/jules/ray_results/PPO/PPO_CartPole-v1_d...
# 3  /Users/jules/ray_results/PPO/PPO_CartPole-v1_d...
#
# [4 rows x 57 columns]

# %% [markdown]
# As stated above, all four combinations actually work about equally well, as far as the `episode_reward_mean` mean is concerned. So what's actually best? What's "good enough" in this case?
#
# It's useful to consider the `training_iteration` (roughly proportional to `episodes_total`) and `timesteps_total`. Let's project out the most interesting data so we can see it more clearly:

# %%
df[['episode_reward_mean', 'training_iteration', 'timesteps_total', 'config/model']].sort_values('timesteps_total', ascending=True)
# Out:
#    episode_reward_mean  training_iteration  timesteps_total  \
# 0               416.97                  11            87978
# 1               409.58                  11            87978
# 2               417.61                  11            87978
# 3               419.04                  13           103974
#
#                   config/model
# 0  {'fcnet_hiddens': [20, 20]}
# 1  {'fcnet_hiddens': [40, 20]}
# 2  {'fcnet_hiddens': [20, 40]}
# 3  {'fcnet_hiddens': [40, 40]}

# %% [markdown]
# We see from this table that the `[20,20]` hyperparameter set took the *most* training iterations, which is understandable as it is the least powerful network configuration. The corresponding number of timesteps was the longest. In contrast, `[40,20]` and `[40,40]` are the fastest to train with almost the same `episode_reward_mean` value.
#
# Since all four combinations perform equally well, perhaps it's best to choose the largest network as it trains the fastest. If we need to train the neural network frequently, then fast training times might be most important. This also suggests that we should be sure the trial sizes we used are really best. In a real-world application, you would want to spend more time on HPO, trying a larger set of possible values.

# %% [markdown]
# ## Analyzing the Results with TensorBoard
#
# Here is the directory where the training data was written for the "best" hyperparameter set:

# %%
analysis.get_best_logdir(metric="episode_reward_mean", mode="max")
# Out:
# '/Users/jules/ray_results/PPO/PPO_CartPole-v1_d328b_00003_3_fcnet_hiddens_0=40,fcnet_hiddens_1=40_2021-11-17_17-06-56'

# %% [markdown]
# There is a separate directory for each trial run.
#
# The easiest way to inspect all the training data, including graphs, is to use [TensorBoard](https://www.tensorflow.org/tensorboard).
#
# 1. If you are runnng on the Anyscale Platform, click the _TensorBoard_ link.
# 2. If you running this notebook on a laptop, open a terminal window using the `+` under the _Edit_ menu, run the following command, then open the URL shown in the output.
#
# ```
# tensorboard --logdir ~/ray_results
# ```

# %% [markdown]
# Here is a screen shot of TensorBoard after the previous Tune run, showing how _scalars_ like the `episdoe_reward_mean` evolved. Some data shown is for runs with trial values of 60 and 80:
#
# ![TensorBoard](../images/tune/TensorBoard-CartPole-HPO-scalars.png)

# %% [markdown]
# Here is a table of the hyperparameter data, similar to what we saw above by looking at the `analysis.dataframe()`:
#
# ![TensorBoard](../images/tune/TensorBoard-CartPole-HPO-hyperparameters.png)

# %% [markdown]
# ## Other Useful Information
#
# The `ray.tune.trial.Trial` object ([documentation](https://docs.ray.io/en/latest/tune/api_docs/internals.html?highlight=Trial#trial-docstring)) records lots of information about particular trials:

# %%
trial = analysis.get_best_trial(metric="episode_reward_mean", mode="max")
trial, type(trial)
# Out:
# (PPO_CartPole-v1_d328b_00003, ray.tune.trial.Trial)

# %%
trial.stopping_criterion
# Out:
# {'episode_reward_mean': 400}

# %%
trial.metric_analysis
# Out:
# {'episode_reward_max': {'max': 500.0,
#   'min': 116.0,
#   'avg': 420.61538461538464,
#   'last': 500.0,
#   'last-5-avg': 500.0,
#   'last-10-avg': 500.0},
#  'episode_reward_min': {'max': 150.0,
#   'min': 8.0,
#   'avg': 72.84615384615384,
#   'last': 150.0,
#   'last-5-avg': 141.6,
#   'last-10-avg': 91.6},
#  'episode_reward_mean': {'max': 419.04,
#   'min': 22.602272727272727,
#   'avg': 224.9199381387843,
#   'last': 419.04,
#   'last-5-avg': 355.02599999999995,
#   'last-10-avg': 278.446},
#  'episode_len_mean': {'max': 419.04,
#   'min': 22.602272727272727,
#   'avg': 224.9199381387843,
#   'last': 419.04,
#   'last-5-avg': 355.02599999999995,
#   'last-10-avg': 278.446},
#  'episodes_this_iter': {'max': 352,
#   'min': 16,
#   'avg': 71.46153846153848,
#   'last': 16,
#   'last-5-avg': 18.6,
#   'last-10-avg': 26.9},
#  'num_healthy_workers': {'max': 3,
#   'min': 3,
#   'avg': 3.0,
#   'last': 3,
#   'last-5-avg': 3.0,
#   'last-10-avg': 3.0},
#  'timesteps_total': {'max': 103974,
#   'min': 7998,
#   'avg': 55986.0,
#   'last': 103974,
#   'last-5-avg': 87978.0,
#   'last-10-avg': 67983.0},
#  'agent_timesteps_total': {'max': 103974,
#   'min': 7998,
#   'avg': 55986.0,
#   'last': 103974,
#   'last-5-avg': 87978.0,
#   'last-10-avg': 67983.0},
#  'done': {'max': True,
#   'min': False,
#   'avg': 0.07692307692307693,
#   'last': True,
#   'last-5-avg': 0.2,
#   'last-10-avg': 0.1},
#  'episodes_total': {'max': 929,
#   'min': 352,
#   'avg': 764.1538461538462,
#   'last': 929,
#   'last-5-avg': 895.0,
#   'last-10-avg': 836.2},
#  'training_iteration': {'max': 13,
#   'min': 1,
#   'avg': 7.0,
#   'last': 13,
#   'last-5-avg': 11.0,
#   'last-10-avg': 8.5},
#  'timestamp': {'max': 1637197790,
#   'min': 1637197738,
#   'avg': 1637197763.5384617,
#   'last': 1637197790,
#   'last-5-avg': 1637197780.8,
#   'last-10-avg': 1637197769.9},
#  'time_this_iter_s': {'max': 4.596135854721069,
#   'min': 4.091415882110596,
#   'avg': 4.289133291978102,
#   'last': 4.456599712371826,
#   'last-5-avg': 4.402432107925415,
#   'last-10-avg': 4.28238000869751},
#  'time_total_s': {'max': 55.75873279571533,
#   'min': 4.596135854721069,
#   'avg': 29.809969810339123,
#   'last': 55.75873279571533,
#   'last-5-avg': 46.88559517860413,
#   'last-10-avg': 36.115502214431764},
#  'pid': {'max': 10241,
#   'min': 10241,
#   'avg': 10241.0,
#   'last': 10241,
#   'last-5-avg': 10241.0,
#   'last-10-avg': 10241.0},
#  'time_since_restore': {'max': 55.75873279571533,
#   'min': 4.596135854721069,
#   'avg': 29.809969810339123,
#   'last': 55.75873279571533,
#   'last-5-avg': 46.88559517860413,
#   'last-10-avg': 36.115502214431764},
#  'timesteps_since_restore': {'max': 0,
#   'min': 0,
#   'avg': 0.0,
#   'last': 0,
#   'last-5-avg': 0.0,
#   'last-10-avg': 0.0},
#  'iterations_since_restore': {'max': 13,
#   'min': 1,
#   'avg': 7.0,
#   'last': 13,
#   'last-5-avg': 11.0,
#   'last-10-avg': 8.5},
#  'sampler_perf/mean_raw_obs_processing_ms': {'max': 0.07093064219047024,
#   'min': 0.058521017029905524,
#   'avg': 0.061740864932560015,
#   'last': 0.058521017029905524,
#   'last-5-avg': 0.05875230760395236,
#   'last-10-avg': 0.05991843270429468},
#  'sampler_perf/mean_inference_ms': {'max': 0.6915563648596382,
#   'min': 0.6562042818564557,
#   'avg': 0.6648230744107344,
#   'last': 0.6634731410719337,
#   'last-5-avg': 0.6597051611045778,
#   'last-10-avg': 0.6596498757902121},
#  'sampler_perf/mean_action_processing_ms': {'max': 0.04657932739953579,
#   'min': 0.044982936209151,
#   'avg': 0.04544834052601322,
#   'last': 0.04557530429395284,
#   'last-5-avg': 0.04529303822668921,
#   'last-10-avg': 0.04521881276364957},
#  'sampler_perf/mean_env_wait_ms': {'max': 0.04716924629309917,
#   'min': 0.04542737816613904,
#   'avg': 0.04593129953759987,
#   'last': 0.04599933119330707,
#   'last-5-avg': 0.0457345025997145,
#   'last-10-avg': 0.04566736946406786},
#  'sampler_perf/mean_env_render_ms': {'max': 0.0,
#   'min': 0.0,
#   'avg': 0.0,
#   'last': 0.0,
#   'last-5-avg': 0.0,
#   'last-10-avg': 0.0},
#  'timers/sample_time_ms': {'max': 4282.834,
#   'min': 2331.619,
#   'avg': 3823.177846153846,
#   'last': 4282.834,
#   'last-5-avg': 4168.906799999999,
#   'last-10-avg': 4027.0946000000004},
#  'timers/sample_throughput': {'max': 3430.235,
#   'min': 1867.455,
#   'avg': 2141.3197692307695,
#   'last': 1867.455,
#   'last-5-avg': 1919.9309999999998,
#   'last-10-avg': 1989.5646999999997},
#  'timers/load_time_ms': {'max': 0.298,
#   'min': 0.288,
#   'avg': 0.29300000000000004,
#   'last': 0.293,
#   'last-5-avg': 0.293,
#   'last-10-avg': 0.2926},
#  'timers/load_throughput': {'max': 27739286.157,
#   'min': 26836834.714,
#   'avg': 27291520.45884615,
#   'last': 27337660.657,
#   'last-5-avg': 27290558.668,
#   'last-10-avg': 27330649.9705},
#  'timers/learn_time_ms': {'max': 2250.945,
#   'min': 2033.183,
#   'avg': 2070.0760000000005,
#   'last': 2073.539,
#   'last-5-avg': 2053.2480000000005,
#   'last-10-avg': 2047.1389},
#  'timers/learn_throughput': {'max': 3933.734,
#   'min': 3553.175,
#   'avg': 3866.3316153846167,
#   'last': 3857.173,
#   'last-5-avg': 3895.4184,
#   'last-10-avg': 3907.043},
#  'timers/update_time_ms': {'max': 1.628,
#   'min': 1.518,
#   'avg': 1.5408461538461535,
#   'last': 1.531,
#   'last-5-avg': 1.523,
#   'last-10-avg': 1.5314},
#  'info/num_steps_sampled': {'max': 103974,
#   'min': 7998,
#   'avg': 55986.0,
#   'last': 103974,
#   'last-5-avg': 87978.0,
#   'last-10-avg': 67983.0},
#  'info/num_agent_steps_sampled': {'max': 103974,
#   'min': 7998,
#   'avg': 55986.0,
#   'last': 103974,
#   'last-5-avg': 87978.0,
#   'last-10-avg': 67983.0},
#  'info/num_steps_trained': {'max': 103974,
#   'min': 7998,
#   'avg': 55986.0,
#   'last': 103974,
#   'last-5-avg': 87978.0,
#   'last-10-avg': 67983.0},
#  'info/num_agent_steps_trained': {'max': 103974,
#   'min': 7998,
#   'avg': 55986.0,
#   'last': 103974,
#   'last-5-avg': 87978.0,
#   'last-10-avg': 67983.0},
#  'config/num_workers': {'max': 3,
#   'min': 3,
#   'avg': 3.0,
#   'last': 3,
#   'last-5-avg': 3.0,
#   'last-10-avg': 3.0},
#  'config/num_envs_per_worker': {'max': 1,
#   'min': 1,
#   'avg': 1.0,
#   'last': 1,
#   'last-5-avg': 1.0,
#   'last-10-avg': 1.0},
#  'config/create_env_on_driver': {'max': False,
#   'min': False,
#   'avg': 0.0,
#   'last': False,
#   'last-5-avg': 0.0,
#   'last-10-avg': 0.0},
#  'config/rollout_fragment_length': {'max': 1333,
#   'min': 1333,
#   'avg': 1333.0,
#   'last': 1333,
#   'last-5-avg': 1333.0,
#   'last-10-avg': 1333.0},
#  'config/gamma': {'max': 0.99,
#   'min': 0.99,
#   'avg': 0.99,
#   'last': 0.99,
#   'last-5-avg': 0.99,
#   'last-10-avg': 0.99},
#  'config/lr': {'max': 5e-05,
#   'min': 5e-05,
#   'avg': 5.000000000000001e-05,
#   'last': 5e-05,
#   'last-5-avg': 5e-05,
#   'last-10-avg': 5.000000000000001e-05},
#  'config/train_batch_size': {'max': 4000,
#   'min': 4000,
#   'avg': 4000.0,
#   'last': 4000,
#   'last-5-avg': 4000.0,
#   'last-10-avg': 4000.0},
#  'config/_tf_policy_handles_more_than_one_loss': {'max': False,
#   'min': False,
#   'avg': 0.0,
#   'last': False,
#   'last-5-avg': 0.0,
#   'last-10-avg': 0.0},
#  'config/soft_horizon': {'max': False,
#   'min': False,
#   'avg': 0.0,
#   'last': False,
#   'last-5-avg': 0.0,
#   'last-10-avg': 0.0},
#  'config/no_done_at_end': {'max': False,
#   'min': False,
#   'avg': 0.0,
#   'last': False,
#   'last-5-avg': 0.0,
#   'last-10-avg': 0.0},
#  'config/remote_worker_envs': {'max': False,
#   'min': False,
#   'avg': 0.0,
#   'last': False,
#   'last-5-avg': 0.0,
#   'last-10-avg': 0.0},
#  'config/remote_env_batch_wait_ms': {'max': 0,
#   'min': 0,
#   'avg': 0.0,
#   'last': 0,
#   'last-5-avg': 0.0,
#   'last-10-avg': 0.0},
#  'config/render_env': {'max': False,
#   'min': False,
#   'avg': 0.0,
#   'last': False,
#   'last-5-avg': 0.0,
#   'last-10-avg': 0.0},
#  'config/record_env': {'max': False,
#   'min': False,
#   'avg': 0.0,
#   'last': False,
#   'last-5-avg': 0.0,
#   'last-10-avg': 0.0},
#  'config/normalize_actions': {'max': True,
#   'min': True,
#   'avg': 1.0,
#   'last': True,
#   'last-5-avg': 1.0,
#   'last-10-avg': 1.0},
#  'config/clip_actions': {'max': False,
#   'min': False,
#   'avg': 0.0,
#   'last': False,
#   'last-5-avg': 0.0,
#   'last-10-avg': 0.0},
#  'config/ignore_worker_failures': {'max': False,
#   'min': False,
#   'avg': 0.0,
#   'last': False,
#   'last-5-avg': 0.0,
#   'last-10-avg': 0.0},
#  'config/log_sys_usage': {'max': True,
#   'min': True,
#   'avg': 1.0,
#   'last': True,
#   'last-5-avg': 1.0,
#   'last-10-avg': 1.0},
#  'config/fake_sampler': {'max': False,
#   'min': False,
#   'avg': 0.0,
#   'last': False,
#   'last-5-avg': 0.0,
#   'last-10-avg': 0.0},
#  'config/eager_tracing': {'max': False,
#   'min': False,
#   'avg': 0.0,
#   'last': False,
#   'last-5-avg': 0.0,
#   'last-10-avg': 0.0},
#  'config/explore': {'max': True,
#   'min': True,
#   'avg': 1.0,
#   'last': True,
#   'last-5-avg': 1.0,
#   'last-10-avg': 1.0},
#  'config/evaluation_num_episodes': {'max': 10,
#   'min': 10,
#   'avg': 10.0,
#   'last': 10,
#   'last-5-avg': 10.0,
#   'last-10-avg': 10.0},
#  'config/evaluation_parallel_to_training': {'max': False,
#   'min': False,
#   'avg': 0.0,
#   'last': False,
#   'last-5-avg': 0.0,
#   'last-10-avg': 0.0},
#  'config/in_evaluation': {'max': False,
#   'min': False,
#   'avg': 0.0,
#   'last': False,
#   'last-5-avg': 0.0,
#   'last-10-avg': 0.0},
#  'config/evaluation_num_workers': {'max': 0,
#   'min': 0,
#   'avg': 0.0,
#   'last': 0,
#   'last-5-avg': 0.0,
#   'last-10-avg': 0.0},
#  'config/sample_async': {'max': False,
#   'min': False,
#   'avg': 0.0,
#   'last': False,
#   'last-5-avg': 0.0,
#   'last-10-avg': 0.0},
#  'config/synchronize_filters': {'max': True,
#   'min': True,
#   'avg': 1.0,
#   'last': True,
#   'last-5-avg': 1.0,
#   'last-10-avg': 1.0},
#  'config/compress_observations': {'max': False,
#   'min': False,
#   'avg': 0.0,
#   'last': False,
#   'last-5-avg': 0.0,
#   'last-10-avg': 0.0},
#  'config/collect_metrics_timeout': {'max': 180,
#   'min': 180,
#   'avg': 180.0,
#   'last': 180,
#   'last-5-avg': 180.0,
#   'last-10-avg': 180.0},
#  'config/metrics_smoothing_episodes': {'max': 100,
#   'min': 100,
#   'avg': 100.0,
#   'last': 100,
#   'last-5-avg': 100.0,
#   'last-10-avg': 100.0},
#  'config/min_iter_time_s': {'max': 0,
#   'min': 0,
#   'avg': 0.0,
#   'last': 0,
#   'last-5-avg': 0.0,
#   'last-10-avg': 0.0},
#  'config/timesteps_per_iteration': {'max': 0,
#   'min': 0,
#   'avg': 0.0,
#   'last': 0,
#   'last-5-avg': 0.0,
#   'last-10-avg': 0.0},
#  'config/num_gpus': {'max': 0,
#   'min': 0,
#   'avg': 0.0,
#   'last': 0,
#   'last-5-avg': 0.0,
#   'last-10-avg': 0.0},
#  'config/_fake_gpus': {'max': False,
#   'min': False,
#   'avg': 0.0,
#   'last': False,
#   'last-5-avg': 0.0,
#   'last-10-avg': 0.0},
#  'config/num_cpus_per_worker': {'max': 1,
#   'min': 1,
#   'avg': 1.0,
#   'last': 1,
#   'last-5-avg': 1.0,
#   'last-10-avg': 1.0},
#  'config/num_gpus_per_worker': {'max': 0,
#   'min': 0,
#   'avg': 0.0,
#   'last': 0,
#   'last-5-avg': 0.0,
#   'last-10-avg': 0.0},
#  'config/num_cpus_for_driver': {'max': 1,
#   'min': 1,
#   'avg': 1.0,
#   'last': 1,
#   'last-5-avg': 1.0,
#   'last-10-avg': 1.0},
#  'config/actions_in_input_normalized': {'max': False,
#   'min': False,
#   'avg': 0.0,
#   'last': False,
#   'last-5-avg': 0.0,
#   'last-10-avg': 0.0},
#  'config/postprocess_inputs': {'max': False,
#   'min': False,
#   'avg': 0.0,
#   'last': False,
#   'last-5-avg': 0.0,
#   'last-10-avg': 0.0},
#  'config/shuffle_buffer_size': {'max': 0,
#   'min': 0,
#   'avg': 0.0,
#   'last': 0,
#   'last-5-avg': 0.0,
#   'last-10-avg': 0.0},
#  'config/output_max_file_size': {'max': 67108864,
#   'min': 67108864,
#   'avg': 67108864.0,
#   'last': 67108864,
#   'last-5-avg': 67108864.0,
#   'last-10-avg': 67108864.0},
#  'config/simple_optimizer': {'max': False,
#   'min': False,
#   'avg': 0.0,
#   'last': False,
#   'last-5-avg': 0.0,
#   'last-10-avg': 0.0},
#  'config/monitor': {'max': -1,
#   'min': -1,
#   'avg': -1.0,
#   'last': -1,
#   'last-5-avg': -1.0,
#   'last-10-avg': -1.0},
#  'config/use_critic': {'max': True,
#   'min': True,
#   'avg': 1.0,
#   'last': True,
#   'last-5-avg': 1.0,
#   'last-10-avg': 1.0},
#  'config/use_gae': {'max': True,
#   'min': True,
#   'avg': 1.0,
#   'last': True,
#   'last-5-avg': 1.0,
#   'last-10-avg': 1.0},
#  'config/lambda': {'max': 1.0,
#   'min': 1.0,
#   'avg': 1.0,
#   'last': 1.0,
#   'last-5-avg': 1.0,
#   'last-10-avg': 1.0},
#  'config/kl_coeff': {'max': 0.2,
#   'min': 0.2,
#   'avg': 0.2,
#   'last': 0.2,
#   'last-5-avg': 0.2,
#   'last-10-avg': 0.19999999999999998},
#  'config/sgd_minibatch_size': {'max': 128,
#   'min': 128,
#   'avg': 128.0,
#   'last': 128,
#   'last-5-avg': 128.0,
#   'last-10-avg': 128.0},
#  'config/shuffle_sequences': {'max': True,
#   'min': True,
#   'avg': 1.0,
#   'last': True,
#   'last-5-avg': 1.0,
#   'last-10-avg': 1.0},
#  'config/num_sgd_iter': {'max': 30,
#   'min': 30,
#   'avg': 30.0,
#   'last': 30,
#   'last-5-avg': 30.0,
#   'last-10-avg': 30.0},
#  'config/vf_loss_coeff': {'max': 1.0,
#   'min': 1.0,
#   'avg': 1.0,
#   'last': 1.0,
#   'last-5-avg': 1.0,
#   'last-10-avg': 1.0},
#  'config/entropy_coeff': {'max': 0.0,
#   'min': 0.0,
#   'avg': 0.0,
#   'last': 0.0,
#   'last-5-avg': 0.0,
#   'last-10-avg': 0.0},
#  'config/clip_param': {'max': 0.3,
#   'min': 0.3,
#   'avg': 0.2999999999999998,
#   'last': 0.3,
#   'last-5-avg': 0.3,
#   'last-10-avg': 0.29999999999999993},
#  'config/vf_clip_param': {'max': 10.0,
#   'min': 10.0,
#   'avg': 10.0,
#   'last': 10.0,
#   'last-5-avg': 10.0,
#   'last-10-avg': 10.0},
#  'config/kl_target': {'max': 0.01,
#   'min': 0.01,
#   'avg': 0.009999999999999997,
#   'last': 0.01,
#   'last-5-avg': 0.01,
#   'last-10-avg': 0.009999999999999998},
#  'config/vf_share_layers': {'max': -1,
#   'min': -1,
#   'avg': -1.0,
#   'last': -1,
#   'last-5-avg': -1.0,
#   'last-10-avg': -1.0},
#  'perf/cpu_util_percent': {'max': 32.28333333333333,
#   'min': 23.433333333333334,
#   'avg': 29.17326007326007,
#   'last': 31.633333333333336,
#   'last-5-avg': 30.351428571428567,
#   'last-10-avg': 29.035714285714285},
#  'perf/ram_util_percent': {'max': 52.699999999999996,
#   'min': 52.6,
#   'avg': 52.64615384615386,
#   'last': 52.6,
#   'last-5-avg': 52.60000000000001,
#   'last-10-avg': 52.63000000000001},
#  'config/model/_use_default_native_models': {'max': False,
#   'min': False,
#   'avg': 0.0,
#   'last': False,
#   'last-5-avg': 0.0,
#   'last-10-avg': 0.0},
#  'config/model/_no_preprocessing': {'max': False,
#   'min': False,
#   'avg': 0.0,
#   'last': False,
#   'last-5-avg': 0.0,
#   'last-10-avg': 0.0},
#  'config/model/free_log_std': {'max': False,
#   'min': False,
#   'avg': 0.0,
#   'last': False,
#   'last-5-avg': 0.0,
#   'last-10-avg': 0.0},
#  'config/model/no_final_linear': {'max': False,
#   'min': False,
#   'avg': 0.0,
#   'last': False,
#   'last-5-avg': 0.0,
#   'last-10-avg': 0.0},
#  'config/model/vf_share_layers': {'max': False,
#   'min': False,
#   'avg': 0.0,
#   'last': False,
#   'last-5-avg': 0.0,
#   'last-10-avg': 0.0},
#  'config/model/use_lstm': {'max': False,
#   'min': False,
#   'avg': 0.0,
#   'last': False,
#   'last-5-avg': 0.0,
#   'last-10-avg': 0.0},
#  'config/model/max_seq_len': {'max': 20,
#   'min': 20,
#   'avg': 20.0,
#   'last': 20,
#   'last-5-avg': 20.0,
#   'last-10-avg': 20.0},
#  'config/model/lstm_cell_size': {'max': 256,
#   'min': 256,
#   'avg': 256.0,
#   'last': 256,
#   'last-5-avg': 256.0,
#   'last-10-avg': 256.0},
#  'config/model/lstm_use_prev_action': {'max': False,
#   'min': False,
#   'avg': 0.0,
#   'last': False,
#   'last-5-avg': 0.0,
#   'last-10-avg': 0.0},
#  'config/model/lstm_use_prev_reward': {'max': False,
#   'min': False,
#   'avg': 0.0,
#   'last': False,
#   'last-5-avg': 0.0,
#   'last-10-avg': 0.0},
#  'config/model/_time_major': {'max': False,
#   'min': False,
#   'avg': 0.0,
#   'last': False,
#   'last-5-avg': 0.0,
#   'last-10-avg': 0.0},
#  'config/model/use_attention': {'max': False,
#   'min': False,
#   'avg': 0.0,
#   'last': False,
#   'last-5-avg': 0.0,
#   'last-10-avg': 0.0},
#  'config/model/attention_num_transformer_units': {'max': 1,
#   'min': 1,
#   'avg': 1.0,
#   'last': 1,
#   'last-5-avg': 1.0,
#   'last-10-avg': 1.0},
#  'config/model/attention_dim': {'max': 64,
#   'min': 64,
#   'avg': 64.0,
#   'last': 64,
#   'last-5-avg': 64.0,
#   'last-10-avg': 64.0},
#  'config/model/attention_num_heads': {'max': 1,
#   'min': 1,
#   'avg': 1.0,
#   'last': 1,
#   'last-5-avg': 1.0,
#   'last-10-avg': 1.0},
#  'config/model/attention_head_dim': {'max': 32,
#   'min': 32,
#   'avg': 32.0,
#   'last': 32,
#   'last-5-avg': 32.0,
#   'last-10-avg': 32.0},
#  'config/model/attention_memory_inference': {'max': 50,
#   'min': 50,
#   'avg': 50.0,
#   'last': 50,
#   'last-5-avg': 50.0,
#   'last-10-avg': 50.0},
#  'config/model/attention_memory_training': {'max': 50,
#   'min': 50,
#   'avg': 50.0,
#   'last': 50,
#   'last-5-avg': 50.0,
#   'last-10-avg': 50.0},
#  'config/model/attention_position_wise_mlp_dim': {'max': 32,
#   'min': 32,
#   'avg': 32.0,
#   'last': 32,
#   'last-5-avg': 32.0,
#   'last-10-avg': 32.0},
#  'config/model/attention_init_gru_gate_bias': {'max': 2.0,
#   'min': 2.0,
#   'avg': 2.0,
#   'last': 2.0,
#   'last-5-avg': 2.0,
#   'last-10-avg': 2.0},
#  'config/model/attention_use_n_prev_actions': {'max': 0,
#   'min': 0,
#   'avg': 0.0,
#   'last': 0,
#   'last-5-avg': 0.0,
#   'last-10-avg': 0.0},
#  'config/model/attention_use_n_prev_rewards': {'max': 0,
#   'min': 0,
#   'avg': 0.0,
#   'last': 0,
#   'last-5-avg': 0.0,
#   'last-10-avg': 0.0},
#  'config/model/framestack': {'max': True,
#   'min': True,
#   'avg': 1.0,
#   'last': True,
#   'last-5-avg': 1.0,
#   'last-10-avg': 1.0},
#  'config/model/dim': {'max': 84,
#   'min': 84,
#   'avg': 84.0,
#   'last': 84,
#   'last-5-avg': 84.0,
#   'last-10-avg': 84.0},
#  'config/model/grayscale': {'max': False,
#   'min': False,
#   'avg': 0.0,
#   'last': False,
#   'last-5-avg': 0.0,
#   'last-10-avg': 0.0},
#  'config/model/zero_mean': {'max': True,
#   'min': True,
#   'avg': 1.0,
#   'last': True,
#   'last-5-avg': 1.0,
#   'last-10-avg': 1.0},
#  'config/model/lstm_use_prev_action_reward': {'max': -1,
#   'min': -1,
#   'avg': -1.0,
#   'last': -1,
#   'last-5-avg': -1.0,
#   'last-10-avg': -1.0},
#  'config/tf_session_args/intra_op_parallelism_threads': {'max': 2,
#   'min': 2,
#   'avg': 2.0,
#   'last': 2,
#   'last-5-avg': 2.0,
#   'last-10-avg': 2.0},
#  'config/tf_session_args/inter_op_parallelism_threads': {'max': 2,
#   'min': 2,
#   'avg': 2.0,
#   'last': 2,
#   'last-5-avg': 2.0,
#   'last-10-avg': 2.0},
#  'config/tf_session_args/log_device_placement': {'max': False,
#   'min': False,
#   'avg': 0.0,
#   'last': False,
#   'last-5-avg': 0.0,
#   'last-10-avg': 0.0},
#  'config/tf_session_args/allow_soft_placement': {'max': True,
#   'min': True,
#   'avg': 1.0,
#   'last': True,
#   'last-5-avg': 1.0,
#   'last-10-avg': 1.0},
#  'config/local_tf_session_args/intra_op_parallelism_threads': {'max': 8,
#   'min': 8,
#   'avg': 8.0,
#   'last': 8,
#   'last-5-avg': 8.0,
#   'last-10-avg': 8.0},
#  'config/local_tf_session_args/inter_op_parallelism_threads': {'max': 8,
#   'min': 8,
#   'avg': 8.0,
#   'last': 8,
#   'last-5-avg': 8.0,
#   'last-10-avg': 8.0},
#  'config/multiagent/policy_map_capacity': {'max': 100,
#   'min': 100,
#   'avg': 100.0,
#   'last': 100,
#   'last-5-avg': 100.0,
#   'last-10-avg': 100.0},
#  'config/tf_session_args/gpu_options/allow_growth': {'max': True,
#   'min': True,
#   'avg': 1.0,
#   'last': True,
#   'last-5-avg': 1.0,
#   'last-10-avg': 1.0},
#  'config/tf_session_args/device_count/CPU': {'max': 1,
#   'min': 1,
#   'avg': 1.0,
#   'last': 1,
#   'last-5-avg': 1.0,
#   'last-10-avg': 1.0},
#  'info/learner/default_policy/learner_stats/cur_kl_coeff': {'max': 0.30000001192092896,
#   'min': 0.004687500186264515,
#   'avg': 0.1368990435193364,
#   'last': 0.004687500186264515,
#   'last-5-avg': 0.01593750063329935,
#   'last-10-avg': 0.09796875389292836},
#  'info/learner/default_policy/learner_stats/cur_lr': {'max': 4.999999873689376e-05,
#   'min': 4.999999873689376e-05,
#   'avg': 4.999999873689376e-05,
#   'last': 4.999999873689376e-05,
#   'last-5-avg': 4.999999873689376e-05,
#   'last-10-avg': 4.999999873689376e-05},
#  'info/learner/default_policy/learner_stats/total_loss': {'max': 2538.0723,
#   'min': 243.9155,
#   'avg': 1694.46189058744,
#   'last': 1562.2595,
#   'last-5-avg': 1830.6585693359375,
#   'last-10-avg': 2011.0896118164062},
#  'info/learner/default_policy/learner_stats/policy_loss': {'max': -0.0059711277,
#   'min': -0.034339286,
#   'avg': -0.015818051922206696,
#   'last': -0.019116174,
#   'last-5-avg': -0.012666853796690702,
#   'last-10-avg': -0.0117377663962543},
#  'info/learner/default_policy/learner_stats/vf_loss': {'max': 2538.0872,
#   'min': 243.94554,
#   'avg': 1694.4764955960788,
#   'last': 1562.2784,
#   'last-5-avg': 1830.671044921875,
#   'last-10-avg': 2011.100927734375},
#  'info/learner/default_policy/learner_stats/vf_explained_var': {'max': 0.11233869,
#   'min': 1.3130327e-05,
#   'avg': 0.03215375005919878,
#   'last': 1.3130327e-05,
#   'last-5-avg': 0.055229601372229806,
#   'last-10-avg': 0.036364770315685746},
#  'info/learner/default_policy/learner_stats/kl': {'max': 0.021524757,
#   'min': 0.0011045727,
#   'avg': 0.006789475043590826,
#   'last': 0.003185835,
#   'last-5-avg': 0.004589163372293115,
#   'last-10-avg': 0.00423738231183961},
#  'info/learner/default_policy/learner_stats/entropy': {'max': 0.67213315,
#   'min': 0.52746373,
#   'avg': 0.5655921055720403,
#   'last': 0.5538782,
#   'last-5-avg': 0.5382897615432739,
#   'last-10-avg': 0.5460470497608185},
#  'info/learner/default_policy/learner_stats/entropy_coeff': {'max': 0.0,
#   'min': 0.0,
#   'avg': 0.0,
#   'last': 0.0,
#   'last-5-avg': 0.0,
#   'last-10-avg': 0.0}}

# %% [markdown]
# How long did it take??

# %%
stats = analysis.stats()
stats
# Out:
# {'start_time': 1637197616.6324868, 'timestamp': 1637197782.09519}

# %%
secs = stats["timestamp"] - stats["start_time"]
print(f'{secs:7.2f} seconds, {secs/60.0:7.2f} minutes')
# Out:
#  165.46 seconds,    2.76 minutes

# %%
analysis.runner_data()
# Out:
# {'_max_pending_trials': 16,
#  '_metric': None,
#  '_total_time': 308.46672654151917,
#  '_iteration': 323,
#  '_has_errored': False,
#  '_fail_fast': False,
#  '_server_port': None,
#  '_cached_trial_decisions': {},
#  '_queued_trial_decisions': {},
#  '_updated_queue': True,
#  '_result_wait_time': 1,
#  '_should_stop_experiment': False,
#  '_local_checkpoint_dir': '/Users/jules/ray_results/PPO',
#  '_remote_checkpoint_dir': None,
#  '_stopper': <ray.tune.stopper.NoopStopper at 0x7fe7521c3e90>,
#  '_resumed': False,
#  '_start_time': 1637197616.6324868,
#  '_last_checkpoint_time': -inf,
#  '_session_str': '2021-11-17_17-06-56',
#  'checkpoint_file': '/Users/jules/ray_results/PPO/experiment_state-2021-11-17_17-06-56.json',
#  '_checkpoint_period': 'auto',
#  'launch_web_server': False}

# %% [markdown]
# We used grid search here, which is a naïve approach. In subsequent lessons, we'll explore how to optimize the search process using some of Tune's built-in algorithms for this purpose.

# %% [markdown]
# ## Exercise - Try More Neural Network Sizes
#
# Repeat the experiment above using the sizes `[20, 40, 60, 80, 100]` or some subset of these numbers, depending on how long you are willing to wait. (It takes about 25 minutes on a recent-vintage laptop.) What combination appears to be best, given the considerations we discussed above?
#
# > **Note:** The exercise solution for this tutorial can be found [here](solutions/01-Understanding-Hyperparameter-Tuning-Solutions.ipynb).

# %%
ray.shutdown()  # "Undo ray.init()".
